# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.model_selection import train_test_split

# %%
file_path = "data/full_df.csv" 
training_images_dir = "data/ODIR-5K/ODIR-5K/Training Images" 
testing_images_dir = "data/ODIR-5K/ODIR-5K/Testing Images"   


data = pd.read_csv(file_path)

# %%
# Parse 'target' column into one-hot encoded labels
data['target'] = data['target'].apply(lambda x: list(map(int, x.strip("[]").split(", "))))
labels = np.array(data['target'].tolist())

# %%
# Correct and assign image paths
data['Left-Fundus'] = data['Left-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))
data['Right-Fundus'] = data['Right-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))

# %%
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

print(f"Number of training samples: {len(train_data)}")
print(f"Number of testing samples: {len(test_data)}")
# Out:
# Number of training samples: 5113
# Number of testing samples: 1279

# %%
IMG_HEIGHT, IMG_WIDTH = 224, 224

# %%
# Define custom dataset
class FundusDataset(Dataset):
    def __init__(self, left_paths, right_paths, labels, transform=None):
        self.left_paths = left_paths
        self.right_paths = right_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # Load and preprocess left and right images
        left_img = cv2.imread(self.left_paths[idx])
        right_img = cv2.imread(self.right_paths[idx])

        # Resize and concatenate
        left_img = cv2.resize(left_img, (IMG_WIDTH, IMG_HEIGHT))
        right_img = cv2.resize(right_img, (IMG_WIDTH, IMG_HEIGHT))
        combined_img = np.concatenate((left_img, right_img), axis=2)  # Concatenate along the channel axis

        # Apply transformations if any
        if self.transform:
            combined_img = self.transform(combined_img)

        # Convert label to tensor
        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        return combined_img, label

# Transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean=[0.5] * 6, std=[0.5] * 6)  # Normalize 6-channel input
])

# %%
train_dataset = FundusDataset(
    train_data['Left-Fundus'].tolist(),
    train_data['Right-Fundus'].tolist(),
    train_data['target'].tolist(),
    transform=transform
)
test_dataset = FundusDataset(
    test_data['Left-Fundus'].tolist(),
    test_data['Right-Fundus'].tolist(),
    test_data['target'].tolist(),
    transform=transform
)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
class FundusCNN(nn.Module):
    def __init__(self, num_classes):
        super(FundusCNN, self).__init__()
        self.conv1 = nn.Conv2d(6, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten = nn.Flatten()

        # Calculate the flattened size dynamically
        self.fc1_input_size = self._get_flattened_size()
        self.fc1 = nn.Linear(self.fc1_input_size, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def _get_flattened_size(self):
        dummy_input = torch.zeros(1, 6, IMG_HEIGHT, IMG_WIDTH)  # Example input
        x = self.pool(nn.functional.relu(self.conv1(dummy_input)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        return int(np.prod(x.size()))

    def forward(self, x):
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = self.flatten(x)
        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = FundusCNN(num_classes=labels.shape[1]).to(device)

# %%
# Define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCEWithLogitsLoss()

# %%
def train_model(model, train_loader, optimizer, criterion, device):
    model.train()
    for epoch in range(10):  # Number of epochs
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward + Optimize
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}")

# %%
def test_model(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            preds = torch.round(torch.sigmoid(outputs))
            correct_predictions += (preds == labels).all(axis=1).sum().item()
            total_samples += labels.size(0)

    avg_loss = total_loss / len(test_loader)
    accuracy = correct_predictions / total_samples
    print(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.4f}")
    return avg_loss, accuracy

# %%
train_model(model, train_loader, optimizer, criterion, device)
print("\nTesting the model on test data...")
test_loss, test_accuracy = test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.34432710241526365
# Epoch 2, Loss: 0.287399728409946
# Epoch 3, Loss: 0.2781493427231908
# Epoch 4, Loss: 0.26793810185045003
# Epoch 5, Loss: 0.260829190351069
# Epoch 6, Loss: 0.24905990529805422
# Epoch 7, Loss: 0.24293717946857213
# Epoch 8, Loss: 0.2309240188449621
# Epoch 9, Loss: 0.22767015937715768
# Epoch 10, Loss: 0.21496192179620266
#
# Testing the model on test data...
# Test Loss: 0.2882, Test Accuracy: 0.3972

# %%
class DeeperCNN(nn.Module):
    def __init__(self, num_classes):
        super(DeeperCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(6, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * 28 * 28, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DeeperCNN(num_classes=labels.shape[1]).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.3121997078880668
# Epoch 2, Loss: 0.2930171752348542
# Epoch 3, Loss: 0.2841109404340386
# Epoch 4, Loss: 0.27648793971166014
# Epoch 5, Loss: 0.27058696998283266
# Epoch 6, Loss: 0.25906306179240346
# Epoch 7, Loss: 0.2496647596359253
# Epoch 8, Loss: 0.2366360009647906
# Epoch 9, Loss: 0.22007160931825637
# Epoch 10, Loss: 0.20899307113140822
# Test Loss: 0.2597, Test Accuracy: 0.2987
# (0.25967072434723376, 0.2986708365910868)

# %%
import torch

torch.cuda.empty_cache()

torch.cuda.reset_accumulated_memory_stats()
torch.cuda.reset_peak_memory_stats()
torch.cuda.reset_max_memory_allocated()
torch.cuda.reset_max_memory_cached()

print("GPU memory cleared!")

# %%
from torchvision.models import resnet18, ResNet18_Weights
import torch.nn as nn
import torch.optim as optim

#weights = ResNet18_Weights.IMAGENET1K_V1  
weights=ResNet18_Weights.DEFAULT
model = resnet18(weights=weights)

model.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust for 6 input channels
model.fc = nn.Linear(model.fc.in_features, labels.shape[1])  # Adjust output for the number of classes


model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.3069136343896389
# Epoch 2, Loss: 0.28414420792832973
# Epoch 3, Loss: 0.2710399144329131
# Epoch 4, Loss: 0.26306209033355116
# Epoch 5, Loss: 0.2545126880519092
# Epoch 6, Loss: 0.247240727301687
# Epoch 7, Loss: 0.23901394717395305
# Epoch 8, Loss: 0.22515542106702924
# Epoch 9, Loss: 0.208184705208987
# Epoch 10, Loss: 0.18488518092781306
# Test Loss: 0.2768, Test Accuracy: 0.4996
# (0.27677437514066694, 0.49960906958561374)

# %%
def train_model(model, train_loader, optimizer, criterion, device):
    model.train()
    for epoch in range(20):  
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward + Optimize
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}")
from torchvision.models import resnet18, ResNet18_Weights
import torch.nn as nn
import torch.optim as optim

#weights = ResNet18_Weights.IMAGENET1K_V1  
weights=ResNet18_Weights.DEFAULT
model = resnet18(weights=weights)

model.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust for 6 input channels
model.fc = nn.Linear(model.fc.in_features, labels.shape[1])  # Adjust output for the number of classes


model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.30285149198025463
# Epoch 2, Loss: 0.27429342502728105
# Epoch 3, Loss: 0.2642074725590646
# Epoch 4, Loss: 0.25768773378804327
# Epoch 5, Loss: 0.24753322498872876
# Epoch 6, Loss: 0.23777932738885282
# Epoch 7, Loss: 0.222606410831213
# Epoch 8, Loss: 0.20503963716328144
# Epoch 9, Loss: 0.18162675183266402
# Epoch 10, Loss: 0.15661577391438186
# Epoch 11, Loss: 0.1363362907897681
# Epoch 12, Loss: 0.11960528686176986
# Epoch 13, Loss: 0.10484163574874401
# Epoch 14, Loss: 0.09567877377849072
# Epoch 15, Loss: 0.08764436475466937
# Epoch 16, Loss: 0.08058427629293874
# Epoch 17, Loss: 0.07104553657118232
# Epoch 18, Loss: 0.06579594750655815
# Epoch 19, Loss: 0.0588947803596966
# Epoch 20, Loss: 0.0557667943648994
# Test Loss: 0.4041, Test Accuracy: 0.6106
# (0.40413015596568586, 0.6106333072713057)

# %%
def train_model(model, train_loader, optimizer, criterion, device):
    model.train()
    for epoch in range(50):  
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward + Optimize
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}")
        
from torchvision.models import resnet18, ResNet18_Weights
import torch.nn as nn
import torch.optim as optim

train_loader = DataLoader(train_dataset, batch_size=32, num_workers=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, num_workers=8, shuffle=False)

#weights = ResNet18_Weights.IMAGENET1K_V1  
weights=ResNet18_Weights.DEFAULT
model = resnet18(weights=weights)

model.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust for 6 input channels
model.fc = nn.Linear(model.fc.in_features, labels.shape[1])  # Adjust output for the number of classes


model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.3088725393638015
# Epoch 2, Loss: 0.2852587480098009
# Epoch 3, Loss: 0.2717562666162848
# Epoch 4, Loss: 0.26330678081139924
# Epoch 5, Loss: 0.2546147517859936
# Epoch 6, Loss: 0.24655858837068081
# Epoch 7, Loss: 0.23700620606541634
# Epoch 8, Loss: 0.22391622764989733
# Epoch 9, Loss: 0.20341461785137654
# Epoch 10, Loss: 0.1803715586196631
# Epoch 11, Loss: 0.15449490454047918
# Epoch 12, Loss: 0.13474518165457994
# Epoch 13, Loss: 0.11722873304970563
# Epoch 14, Loss: 0.10039609172381461
# Epoch 15, Loss: 0.08879498860333115
# Epoch 16, Loss: 0.08236858196323738
# Epoch 17, Loss: 0.0751825044164434
# Epoch 18, Loss: 0.06541310301981866
# Epoch 19, Loss: 0.05990673466585576
# Epoch 20, Loss: 0.056420024135150015
# Epoch 21, Loss: 0.05113081146264449
# Epoch 22, Loss: 0.0488740139931906
# Epoch 23, Loss: 0.046250163397053255
# Epoch 24, Loss: 0.04393439340637997
# Epoch 25, Loss: 0.043226481712190436
# Epoch 26, Loss: 0.04213545227539726
# Epoch 27, Loss: 0.04080969077767804
# Epoch 28, Loss: 0.04086752092116512
# Epoch 29, Loss: 0.040197073854506014
# Epoch 30, Loss: 0.039858092734357344
# Epoch 31, Loss: 0.04160150951356627
# Epoch 32, Loss: 0.10965616370667704
# Epoch 33, Loss: 0.07370105308946222
# Epoch 34, Loss: 0.04968881636741571
# Epoch 35, Loss: 0.04267594776902115
# Epoch 36, Loss: 0.040880702321010175
# Epoch 37, Loss: 0.040346785163274036
# Epoch 38, Loss: 0.0395448088995181
# Epoch 39, Loss: 0.039079510601004584
# Epoch 40, Loss: 0.0388510768651031
# Epoch 41, Loss: 0.03879019495216198
# Epoch 42, Loss: 0.038102823941153476
# Epoch 43, Loss: 0.038006081158528104
# Epoch 44, Loss: 0.03814747328287922
# Epoch 45, Loss: 0.03832538853166625
# Epoch 46, Loss: 0.04660417709965259
# Epoch 47, Loss: 0.10825348559301347
# Epoch 48, Loss: 0.05054100942215882
# Epoch 49, Loss: 0.042240480057080275
# Epoch 50, Loss: 0.040719933196669444
# Test Loss: 0.6939, Test Accuracy: 0.6231
# (0.6939314991235733, 0.6231430805316653)

# %%
from torchvision.models import resnet18
from torchvision import transforms


def train_model(model, train_loader, optimizer, criterion, device):
    model.train()
    for epoch in range(10):  
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}")

transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
    transforms.RandomRotation(10),  # Randomly rotate the image
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Random crop and resize
    transforms.Normalize(mean=[0.5] * 6, std=[0.5] * 6)  # Normalize 6-channel input
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5] * 6, std=[0.5] * 6)  # No augmentation for testing
])

train_dataset = FundusDataset(
    train_data['Left-Fundus'].tolist(),
    train_data['Right-Fundus'].tolist(),
    train_data['target'].tolist(),
    transform=transform_train
)
test_dataset = FundusDataset(
    test_data['Left-Fundus'].tolist(),
    test_data['Right-Fundus'].tolist(),
    test_data['target'].tolist(),
    transform=transform_test
)

train_loader = DataLoader(train_dataset, batch_size=32, num_workers=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, num_workers=8, shuffle=False)

model = resnet18(pretrained=True)
model.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust input channels to 6
model.fc = nn.Linear(model.fc.in_features, labels.shape[1])  # Adjust output classes
model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)

test_loss, test_accuracy = test_model(model, test_loader, criterion, device)
# Out:
# Epoch 1, Loss: 0.305388648994267
# Epoch 2, Loss: 0.2893676109611988
# Epoch 3, Loss: 0.27777685802429913
# Epoch 4, Loss: 0.27069378094747665
# Epoch 5, Loss: 0.26514550345018506
# Epoch 6, Loss: 0.2609480190090835
# Epoch 7, Loss: 0.2572805553674698
# Epoch 8, Loss: 0.25450759632512926
# Epoch 9, Loss: 0.2523126413114369
# Epoch 10, Loss: 0.25011427691206334
# Test Loss: 0.2797, Test Accuracy: 0.4550

# %%
from torchvision.models import resnet50, ResNet50_Weights
import torch.nn as nn
import torch.optim as optim

weights = ResNet50_Weights.DEFAULT
model = resnet50(weights=weights)

model.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust for 6 input channels
model.fc = nn.Linear(model.fc.in_features, labels.shape[1])  # Adjust output for the number of classes

model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /home/spandan/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:08<00:00, 12.2MB/s]
# Epoch 1, Loss: 0.30010922681540253
# Epoch 2, Loss: 0.2792366216890514
# Epoch 3, Loss: 0.2634122113697231
# Epoch 4, Loss: 0.25498043056577446
# Epoch 5, Loss: 0.24627583706751466
# Epoch 6, Loss: 0.23434898676350713
# Epoch 7, Loss: 0.22154965419322253
# Epoch 8, Loss: 0.20625313641503454
# Epoch 9, Loss: 0.1855567626655102
# Epoch 10, Loss: 0.16920666061341763
# Test Loss: 0.2521, Test Accuracy: 0.4957
# (0.2521042112261057, 0.49569976544175137)

# %%
from sklearn.ensemble import RandomForestClassifier
import torch.nn as nn
import torch
from torchvision.models import resnet18, ResNet18_Weights
import torch.optim as optim
# Load pretrained ResNet18 and adjust for 6 input channels
weights=ResNet18_Weights.DEFAULT
resnet = resnet18(weights=weights)
# Modify the first convolutional layer
resnet.conv1 = nn.Conv2d(
    6, 64, kernel_size=7, stride=2, padding=3, bias=False
)  # Change input channels to 6
resnet.fc = nn.Identity()  # Remove the classification head for feature extraction
resnet = resnet.to(device)

# Extract features function
def extract_features(loader):
    features, labels = [], []
    resnet.eval()
    with torch.no_grad():
        for inputs, lbls in loader:
            inputs = inputs.to(device)
            feat = resnet(inputs).cpu().numpy()
            features.append(feat)
            labels.append(lbls.numpy())
    return np.vstack(features), np.vstack(labels)

train_loader = DataLoader(train_dataset, batch_size=32, num_workers=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, num_workers=8, shuffle=False)
# Extract features for training and testing sets
train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

# Train a Random Forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(train_features, train_labels)

# Test the Random Forest classifier
predictions = clf.predict(test_features)
accuracy = (predictions == test_labels).mean()
print("Random Forest Accuracy with ResNet Features:", accuracy)
# Out:
# Random Forest Accuracy with ResNet Features: 0.8808639562157936

# %%
from torchvision.models import efficientnet_b0

model = efficientnet_b0(pretrained=True)
model.features[0][0] = nn.Conv2d(6, 32, kernel_size=3, stride=2, padding=1, bias=False)  # Adjust input channels
model.classifier[1] = nn.Linear(model.classifier[1].in_features, labels.shape[1])  # Adjust output classes
model = model.to(device)
train_loader = DataLoader(train_dataset, batch_size=32, num_workers=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, num_workers=8, shuffle=False)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_model(model, train_loader, optimizer, criterion, device)
test_model(model, test_loader, criterion, device)
# Out:
# /home/spandan/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/spandan/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.2894620593637228
# Epoch 2, Loss: 0.2562329418957233
# Epoch 3, Loss: 0.24414443271234632
# Epoch 4, Loss: 0.23514638980850577
# Epoch 5, Loss: 0.22638313770294188
# Epoch 6, Loss: 0.2196933708153665
# Epoch 7, Loss: 0.21165706971660256
# Epoch 8, Loss: 0.20746300062164663
# Epoch 9, Loss: 0.19929902590811252
# Epoch 10, Loss: 0.19423500169068575
# Test Loss: 0.2531, Test Accuracy: 0.4934
# (0.2530756704509258, 0.49335418295543393)

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from torchvision import transforms
from transformers import ViTForImageClassification, ViTConfig

from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

file_path = "data/full_df.csv"
training_images_dir = "data/ODIR-5K/ODIR-5K/Training Images"

data = pd.read_csv(file_path)

data['Left-Fundus'] = data['Left-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))
data['Right-Fundus'] = data['Right-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))

data['target'] = data['target'].apply(lambda x: list(map(int, x.strip("[]").split(", "))))
labels = torch.tensor(data['target'].tolist())

class FundusDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        left_img_path = self.df.iloc[idx]['Left-Fundus']
        right_img_path = self.df.iloc[idx]['Right-Fundus']
        label = torch.tensor(self.df.iloc[idx]['target'])

        try:
            left_img = Image.open(left_img_path).convert("RGB")
        except:
            left_img = Image.new("RGB", (224, 224))

        try:
            right_img = Image.open(right_img_path).convert("RGB")
        except:
            right_img = Image.new("RGB", (224, 224))

        if self.transform:
            left_img = self.transform(left_img)
            right_img = self.transform(right_img)

        # Concatenate left and right images along the channel dimension
        combined_img = torch.cat([left_img, right_img], dim=0)

        return combined_img, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

train_split = int(0.8 * len(data))
train_data = data[:train_split]
test_data  = data[train_split:]

train_dataset = FundusDataset(train_data, transform=transform)
test_dataset  = FundusDataset(test_data, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=8)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False, num_workers=8)

config = ViTConfig.from_pretrained('google/vit-base-patch16-224')
config.num_labels = labels.shape[1]
config.image_size = 224  
config.num_channels = 6  

model = ViTForImageClassification.from_pretrained(
    'google/vit-base-patch16-224',
    config=config,
    ignore_mismatched_sizes=True
)

model.vit.embeddings.patch_embeddings.projection = nn.Conv2d(
    in_channels=6,
    out_channels=768,
    kernel_size=16,
    stride=16,
    bias=False
)

model = model.to(device)


criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


def train_model(model, train_loader, optimizer, criterion, device, epochs=10):

    model.train()
    
    for epoch in range(epochs):
        running_loss = 0.0
        
        all_preds = []
        all_labels = []
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            
            outputs = model(inputs).logits
            loss = criterion(outputs, labels.float())
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            # Convert logits to 0/1 predictions
            preds = (torch.sigmoid(outputs) > 0.5).float()
            all_preds.append(preds.detach().cpu())
            all_labels.append(labels.detach().cpu())
        
        epoch_loss = running_loss / len(train_loader)
        
        all_preds  = torch.cat(all_preds, dim=0).numpy()
        all_labels = torch.cat(all_labels, dim=0).numpy()
        
        precision_micro = precision_score(all_labels, all_preds, average='micro', zero_division=0)
        precision_macro = precision_score(all_labels, all_preds, average='macro', zero_division=0)
        recall_micro    = recall_score(all_labels, all_preds, average='micro', zero_division=0)
        recall_macro    = recall_score(all_labels, all_preds, average='macro', zero_division=0)
        f1_micro        = f1_score(all_labels, all_preds, average='micro', zero_division=0)
        f1_macro        = f1_score(all_labels, all_preds, average='macro', zero_division=0)
        
        # Exact match ratio (sample-level accuracy for all labels)
        exact_matches = np.all(all_labels == all_preds, axis=1).sum()
        exact_match_ratio = exact_matches / all_labels.shape[0]
        
        # Label-based accuracy (micro-style): how many individual labels are correct
        correct_labels = (all_preds == all_labels).sum()
        total_labels   = all_labels.size  # number of elements in all_labels
        label_accuracy = correct_labels / total_labels
        
        # Print training metrics for the epoch
        print(f"\nEpoch [{epoch+1}/{epochs}]")
        print(f"  Training Loss: {epoch_loss:.4f}")
        print(f"  Precision (Micro/Macro): {precision_micro:.4f} / {precision_macro:.4f}")
        print(f"  Recall (Micro/Macro):    {recall_micro:.4f} / {recall_macro:.4f}")
        print(f"  F1-score (Micro/Macro):  {f1_micro:.4f} / {f1_macro:.4f}")
        print(f"  Exact Match Ratio:       {exact_match_ratio:.4f}")
        print(f"  Label-based Accuracy:    {label_accuracy:.4f}")


def test_model(model, test_loader, criterion, device):

    model.eval()
    total_loss = 0.0
    
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs).logits
            loss = criterion(outputs, labels.float())
            total_loss += loss.item()
            
            preds = (torch.sigmoid(outputs) > 0.5).float()
            all_preds.append(preds.detach().cpu())
            all_labels.append(labels.detach().cpu())
    
    avg_loss = total_loss / len(test_loader)
    
    all_preds  = torch.cat(all_preds, dim=0).numpy()
    all_labels = torch.cat(all_labels, dim=0).numpy()
    
    precision_micro = precision_score(all_labels, all_preds, average='micro', zero_division=0)
    precision_macro = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall_micro    = recall_score(all_labels, all_preds, average='micro', zero_division=0)
    recall_macro    = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1_micro        = f1_score(all_labels, all_preds, average='micro', zero_division=0)
    f1_macro        = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    
    exact_matches = np.all(all_labels == all_preds, axis=1).sum()
    exact_match_ratio = exact_matches / all_labels.shape[0]
    
    correct_labels = (all_preds == all_labels).sum()
    total_labels   = all_labels.size
    label_accuracy = correct_labels / total_labels
    
    per_label_precision = precision_score(all_labels, all_preds, average=None, zero_division=0)
    per_label_recall    = recall_score(all_labels, all_preds, average=None, zero_division=0)
    
    print("\nTest Set Evaluation:")
    print(f"  Test Loss: {avg_loss:.4f}")
    print(f"  Precision (Micro/Macro): {precision_micro:.4f} / {precision_macro:.4f}")
    print(f"  Recall (Micro/Macro):    {recall_micro:.4f} / {recall_macro:.4f}")
    print(f"  F1-score (Micro/Macro):  {f1_micro:.4f} / {f1_macro:.4f}")
    print(f"  Exact Match Ratio:       {exact_match_ratio:.4f}")
    print(f"  Label-based Accuracy:    {label_accuracy:.4f}")
    print(f"  Per-label Precision:     {per_label_precision}")
    print(f"  Per-label Recall:        {per_label_recall}")


train_model(model, train_loader, optimizer, criterion, device, epochs=10)
test_model(model, test_loader, criterion, device)
# Out:
# 2025-01-26 21:16:10.614386: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737906370.637228  187327 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737906370.651472  187327 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-26 21:16:10.717136: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([8]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([8, 768]) in the model instantiated
# - vit.embeddings.patch_embeddings.projection.weight: found shape torch.Size([768, 3, 16, 16]) in the checkpoint and torch.Size([768, 6, 16, 16]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch [1/10]
#   Training Loss: 0.3299
#   Precision (Micro/Macro): 0.3208 / 0.1073
#   Recall (Micro/Macro):    0.0434 / 0.0168
#   F1-score (Micro/Macro):  0.0765 / 0.0276
#   Exact Match Ratio:       0.0377
#   Label-based Accuracy:    0.8689
#
# Epoch [2/10]
#   Training Loss: 0.3199
#   Precision (Micro/Macro): 0.4545 / 0.0568
#   Recall (Micro/Macro):    0.0196 / 0.0059
#   F1-score (Micro/Macro):  0.0375 / 0.0106
#   Exact Match Ratio:       0.0196
#   Label-based Accuracy:    0.8745
#
# Epoch [3/10]
#   Training Loss: 0.3175
#   Precision (Micro/Macro): 0.4484 / 0.0560
#   Recall (Micro/Macro):    0.0348 / 0.0105
#   F1-score (Micro/Macro):  0.0646 / 0.0176
#   Exact Match Ratio:       0.0348
#   Label-based Accuracy:    0.8740
#
# Epoch [4/10]
#   Training Loss: 0.3138
#   Precision (Micro/Macro): 0.4476 / 0.0560
#   Recall (Micro/Macro):    0.0334 / 0.0100
#   F1-score (Micro/Macro):  0.0622 / 0.0170
#   Exact Match Ratio:       0.0334
#   Label-based Accuracy:    0.8740
#
# Epoch [5/10]
#   Training Loss: 0.3135
#   Precision (Micro/Macro): 0.4869 / 0.0609
#   Recall (Micro/Macro):    0.0544 / 0.0163
#   F1-score (Micro/Macro):  0.0978 / 0.0257
#   Exact Match Ratio:       0.0544
#   Label-based Accuracy:    0.8746
#
# Epoch [6/10]
#   Training Loss: 0.3119
#   Precision (Micro/Macro): 0.4723 / 0.1841
#   Recall (Micro/Macro):    0.0616 / 0.0189
#   F1-score (Micro/Macro):  0.1090 / 0.0290
#   Exact Match Ratio:       0.0614
#   Label-based Accuracy:    0.8741
#
# Epoch [7/10]
#   Training Loss: 0.3102
#   Precision (Micro/Macro): 0.4609 / 0.2267
#   Recall (Micro/Macro):    0.0518 / 0.0197
#   F1-score (Micro/Macro):  0.0932 / 0.0325
#   Exact Match Ratio:       0.0516
#   Label-based Accuracy:    0.8739
#
# Epoch [8/10]
#   Training Loss: 0.3074
#   Precision (Micro/Macro): 0.5046 / 0.2283
#   Recall (Micro/Macro):    0.0542 / 0.0282
#   F1-score (Micro/Macro):  0.0978 / 0.0477
#   Exact Match Ratio:       0.0542
#   Label-based Accuracy:    0.8751
#
# Epoch [9/10]
#   Training Loss: 0.3046
#   Precision (Micro/Macro): 0.5142 / 0.2254
#   Recall (Micro/Macro):    0.0994 / 0.0554
#   F1-score (Micro/Macro):  0.1665 / 0.0826
#   Exact Match Ratio:       0.0994
#   Label-based Accuracy:    0.8757
#
# Epoch [10/10]
#   Training Loss: 0.3054
#   Precision (Micro/Macro): 0.5318 / 0.2373
#   Recall (Micro/Macro):    0.0686 / 0.0450
#   F1-score (Micro/Macro):  0.1216 / 0.0706
#   Exact Match Ratio:       0.0686
#   Label-based Accuracy:    0.8760
#
# Test Set Evaluation:
#   Test Loss: 0.2343
#   Precision (Micro/Macro): 0.0000 / 0.0000
#   Recall (Micro/Macro):    0.0000 / 0.0000
#   F1-score (Micro/Macro):  0.0000 / 0.0000
#   Exact Match Ratio:       0.0000
#   Label-based Accuracy:    0.8749
#   Per-label Precision:     [0. 0. 0. 0. 0. 0. 0. 0.]
#   Per-label Recall:        [0. 0. 0. 0. 0. 0. 0. 0.]

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torchvision.models import resnet18
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# Paths and dataset
file_path = "data/full_df.csv"  # Path to your CSV file
training_images_dir = "data/ODIR-5K/ODIR-5K/Training Images"
testing_images_dir = "data/ODIR-5K/ODIR-5K/Testing Images"

# Load dataset
data = pd.read_csv(file_path)

# Parse 'target' column into one-hot encoded labels
data['target'] = data['target'].apply(lambda x: list(map(int, x.strip("[]").split(", "))))
labels = np.array(data['target'].tolist())

# Assign image paths
data['Left-Fundus'] = data['Left-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))
data['Right-Fundus'] = data['Right-Fundus'].apply(lambda x: os.path.join(training_images_dir, os.path.basename(x)))

# Group images by PatientID (Add a unique identifier if not present)
if 'PatientID' not in data.columns:
    data['PatientID'] = data.index // 2  # Assuming two images per patient

# Filter patients with valid images
valid_patients = []
for patient_id in data['PatientID'].unique():
    patient_data = data[data['PatientID'] == patient_id]
    valid = True
    for _, row in patient_data.iterrows():
        left_img_path = row['Left-Fundus']
        right_img_path = row['Right-Fundus']
        if not os.path.exists(left_img_path) or not os.path.exists(right_img_path):
            valid = False
            break
    if valid:
        valid_patients.append(patient_id)

data = data[data['PatientID'].isin(valid_patients)]
print(f"Number of valid patients: {len(valid_patients)}")

# Define image size and transformations
IMG_HEIGHT, IMG_WIDTH = 224, 224
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5] * 6, std=[0.5] * 6),
])

# Define custom dataset
class FundusSequenceDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.valid_patient_ids = self.data['PatientID'].unique()

    def __len__(self):
        return len(self.valid_patient_ids)

    def __getitem__(self, idx):
        patient_id = self.valid_patient_ids[idx]
        patient_data = self.data[self.data['PatientID'] == patient_id]
        images = []
        labels = None

        for _, row in patient_data.iterrows():
            left_img_path = row['Left-Fundus']
            right_img_path = row['Right-Fundus']

            # Load images
            left_img = cv2.imread(left_img_path)
            right_img = cv2.imread(right_img_path)

            if left_img is None or right_img is None:
                print(f"Skipping corrupted images: {left_img_path}, {right_img_path}")
                continue

            # Resize and concatenate
            left_img = cv2.resize(left_img, (IMG_WIDTH, IMG_HEIGHT))
            right_img = cv2.resize(right_img, (IMG_WIDTH, IMG_HEIGHT))
            combined_img = np.concatenate((left_img, right_img), axis=2)

            # Apply transformations
            if self.transform:
                combined_img = self.transform(combined_img)
            images.append(combined_img)

            # Use the same label for all images in the sequence
            labels = torch.tensor(row['target'], dtype=torch.float32)

        if not images:
            print(f"Skipping PatientID {patient_id} due to no valid images.")
            return None  # Mark invalid patient to skip later

        images = torch.stack(images)
        return images, labels


# Split dataset by PatientID
train_ids, test_ids = train_test_split(data['PatientID'].unique(), test_size=0.2, random_state=42)
train_data = data[data['PatientID'].isin(train_ids)]
test_data = data[data['PatientID'].isin(test_ids)]

train_dataset = FundusSequenceDataset(train_data, transform=transform)
test_dataset = FundusSequenceDataset(test_data, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)  # Sequence per batch
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# CNN Feature Extractor
class CNNFeatureExtractor(nn.Module):
    def __init__(self):
        super(CNNFeatureExtractor, self).__init__()
        self.resnet = resnet18(pretrained=True)
        self.resnet.conv1 = nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False)  # Adjust for 6 channels
        nn.init.kaiming_normal_(self.resnet.conv1.weight[:, :3, :, :], mode="fan_out", nonlinearity="relu")
        nn.init.zeros_(self.resnet.conv1.weight[:, 3:, :, :])
        self.resnet.fc = nn.Identity()  # Remove classification head

    def forward(self, x):
        return self.resnet(x)

# CNN + RNN Model
class CNNRNNModel(nn.Module):
    def __init__(self, cnn_feature_size, rnn_hidden_size, num_classes):
        super(CNNRNNModel, self).__init__()
        self.cnn = CNNFeatureExtractor()
        self.rnn = nn.LSTM(cnn_feature_size, rnn_hidden_size, batch_first=True)
        self.fc = nn.Linear(rnn_hidden_size, num_classes)

    def forward(self, x):
        batch_size, seq_len, _, _, _ = x.size()
        x = x.view(batch_size * seq_len, 6, 224, 224)  # Flatten batch and sequence
        features = self.cnn(x)
        features = features.view(batch_size, seq_len, -1)  # Reshape for RNN
        _, (hidden, _) = self.rnn(features)
        return self.fc(hidden[-1])  # Use the last hidden state

# Model parameters
cnn_feature_size = 512  # ResNet18 outputs 512 features
rnn_hidden_size = 256
num_classes = labels.shape[1]

# Instantiate model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNRNNModel(cnn_feature_size, rnn_hidden_size, num_classes).to(device)

# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
def train_model(model, train_loader, optimizer, criterion, device, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}")

# Testing loop
def test_model(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            preds = torch.round(torch.sigmoid(outputs))
            correct_predictions += (preds == labels).all(axis=1).sum().item()
            total_samples += labels.size(0)

    avg_loss = total_loss / len(test_loader)
    accuracy = correct_predictions / total_samples
    print(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.4f}")
    return avg_loss, accuracy

# Train and evaluate
train_model(model, train_loader, optimizer, criterion, device, num_epochs=10)
test_loss, test_accuracy = test_model(model, test_loader, criterion, device)
# Out:
# Number of valid patients: 3196
# /home/spandan/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/spandan/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.3068171671864246
# Epoch 2, Loss: 0.30360736502611396
# Epoch 3, Loss: 0.3037444114515992
# Epoch 4, Loss: 0.3025095158071492
# Epoch 5, Loss: 0.3032484085376321
# Epoch 6, Loss: 0.3024349377486208
# Epoch 7, Loss: 0.30247978627366917
# Epoch 8, Loss: 0.3026329233647792
# Epoch 9, Loss: 0.30207242571540377
# Epoch 10, Loss: 0.30236809604826015
# Test Loss: 0.2993, Test Accuracy: 0.0000

# %%
print(f"Training Patients: {len(train_data['PatientID'].unique())}")
print(f"Testing Patients: {len(test_data['PatientID'].unique())}")
# Out:
# Training Patients: 2556
# Testing Patients: 640

# %%
missing_files = []
for path in data['Left-Fundus'].tolist() + data['Right-Fundus'].tolist():
    if not os.path.exists(path):
        missing_files.append(path)

print(f"Number of missing files: {len(missing_files)}")
if missing_files:
    print("Missing files:", missing_files[:10])  # Print a few missing file paths for debugging
# Out:
# Number of missing files: 0

# %%
for patient_id in data['PatientID'].unique():
    patient_data = data[data['PatientID'] == patient_id]
    left_images = patient_data['Left-Fundus'].tolist()
    right_images = patient_data['Right-Fundus'].tolist()
    print(f"Patient {patient_id}: {len(left_images)} left, {len(right_images)} right images")
# Out:
# Patient 0: 2 left, 2 right images
# Patient 1: 2 left, 2 right images
# Patient 2: 2 left, 2 right images
# Patient 3: 2 left, 2 right images
# Patient 4: 2 left, 2 right images
# Patient 5: 2 left, 2 right images
# Patient 6: 2 left, 2 right images
# Patient 7: 2 left, 2 right images
# Patient 8: 2 left, 2 right images
# Patient 9: 2 left, 2 right images
# Patient 10: 2 left, 2 right images
# Patient 11: 2 left, 2 right images
# Patient 12: 2 left, 2 right images
# Patient 13: 2 left, 2 right images
# Patient 14: 2 left, 2 right images
# Patient 15: 2 left, 2 right images
# Patient 16: 2 left, 2 right images
# Patient 17: 2 left, 2 right images
# Patient 18: 2 left, 2 right images
# Patient 19: 2 left, 2 right images
# Patient 20: 2 left, 2 right images
# Patient 21: 2 left, 2 right images
# Patient 22: 2 left, 2 right images
# Patient 23: 2 left, 2 right images
# Patient 24: 2 left, 2 right images
# Patient 25: 2 left, 2 right images
# Patient 26: 2 left, 2 right images
# Patient 27: 2 left, 2 right images
# Patient 28: 2 left, 2 right images
# Patient 29: 2 left, 2 right images
# Patient 30: 2 left, 2 right images
# Patient 31: 2 left, 2 right images
# Patient 32: 2 left, 2 right images
# Patient 33: 2 left, 2 right images
# Patient 34: 2 left, 2 right images
# Patient 35: 2 left, 2 right images
# Patient 36: 2 left, 2 right images
# Patient 37: 2 left, 2 right images
# Patient 38: 2 left, 2 right images
# Patient 39: 2 left, 2 right images
# Patient 40: 2 left, 2 right images
# Patient 41: 2 left, 2 right images
# Patient 42: 2 left, 2 right images
# Patient 43: 2 left, 2 right images
# Patient 44: 2 left, 2 right images
# Patient 45: 2 left, 2 right images
# Patient 46: 2 left, 2 right images
# Patient 47: 2 left, 2 right images
# Patient 48: 2 left, 2 right images
# Patient 49: 2 left, 2 right images
# Patient 50: 2 left, 2 right images
# Patient 51: 2 left, 2 right images
# Patient 52: 2 left, 2 right images
# Patient 53: 2 left, 2 right images
# Patient 54: 2 left, 2 right images
# Patient 55: 2 left, 2 right images
# Patient 56: 2 left, 2 right images
# Patient 57: 2 left, 2 right images
# Patient 58: 2 left, 2 right images
# Patient 59: 2 left, 2 right images
# Patient 60: 2 left, 2 right images
# Patient 61: 2 left, 2 right images
# Patient 62: 2 left, 2 right images
# Patient 63: 2 left, 2 right images
# Patient 64: 2 left, 2 right images
# Patient 65: 2 left, 2 right images
# Patient 66: 2 left, 2 right images
# Patient 67: 2 left, 2 right images
# Patient 68: 2 left, 2 right images
# Patient 69: 2 left, 2 right images
# Patient 70: 2 left, 2 right images
# Patient 71: 2 left, 2 right images
# Patient 72: 2 left, 2 right images
# Patient 73: 2 left, 2 right images
# Patient 74: 2 left, 2 right images
# Patient 75: 2 left, 2 right images
# Patient 76: 2 left, 2 right images
# Patient 77: 2 left, 2 right images
# Patient 78: 2 left, 2 right images
# Patient 79: 2 left, 2 right images
# Patient 80: 2 left, 2 right images
# Patient 81: 2 left, 2 right images
# Patient 82: 2 left, 2 right images
# Patient 83: 2 left, 2 right images
# Patient 84: 2 left, 2 right images
# Patient 85: 2 left, 2 right images
# Patient 86: 2 left, 2 right images
# Patient 87: 2 left, 2 right images
# Patient 88: 2 left, 2 right images
# Patient 89: 2 left, 2 right images
# Patient 90: 2 left, 2 right images
# Patient 91: 2 left, 2 right images
# Patient 92: 2 left, 2 right images
# Patient 93: 2 left, 2 right images
# Patient 94: 2 left, 2 right images
# Patient 95: 2 left, 2 right images
# Patient 96: 2 left, 2 right images
# Patient 97: 2 left, 2 right images
# Patient 98: 2 left, 2 right images
# Patient 99: 2 left, 2 right images
# Patient 100: 2 left, 2 right images
# Patient 101: 2 left, 2 right images
# Patient 102: 2 left, 2 right images
# Patient 103: 2 left, 2 right images
# Patient 104: 2 left, 2 right images
# Patient 105: 2 left, 2 right images
# Patient 106: 2 left, 2 right images
# Patient 107: 2 left, 2 right images
# Patient 108: 2 left, 2 right images
# Patient 109: 2 left, 2 right images
# Patient 110: 2 left, 2 right images
# Patient 111: 2 left, 2 right images
# Patient 112: 2 left, 2 right images
# Patient 113: 2 left, 2 right images
# Patient 114: 2 left, 2 right images
# Patient 115: 2 left, 2 right images
# Patient 116: 2 left, 2 right images
# Patient 117: 2 left, 2 right images
# Patient 118: 2 left, 2 right images
# Patient 119: 2 left, 2 right images
# Patient 120: 2 left, 2 right images
# Patient 121: 2 left, 2 right images
# Patient 122: 2 left, 2 right images
# Patient 123: 2 left, 2 right images
# Patient 124: 2 left, 2 right images
# Patient 125: 2 left, 2 right images
# Patient 126: 2 left, 2 right images
# Patient 127: 2 left, 2 right images
# Patient 128: 2 left, 2 right images
# Patient 129: 2 left, 2 right images
# Patient 130: 2 left, 2 right images
# Patient 131: 2 left, 2 right images
# Patient 132: 2 left, 2 right images
# Patient 133: 2 left, 2 right images
# Patient 134: 2 left, 2 right images
# Patient 135: 2 left, 2 right images
# Patient 136: 2 left, 2 right images
# Patient 137: 2 left, 2 right images
# Patient 138: 2 left, 2 right images
# Patient 139: 2 left, 2 right images
# Patient 140: 2 left, 2 right images
# Patient 141: 2 left, 2 right images
# Patient 142: 2 left, 2 right images
# Patient 143: 2 left, 2 right images
# Patient 144: 2 left, 2 right images
# Patient 145: 2 left, 2 right images
# Patient 146: 2 left, 2 right images
# Patient 147: 2 left, 2 right images
# Patient 148: 2 left, 2 right images
# Patient 149: 2 left, 2 right images
# Patient 150: 2 left, 2 right images
# Patient 151: 2 left, 2 right images
# Patient 152: 2 left, 2 right images
# Patient 153: 2 left, 2 right images
# Patient 154: 2 left, 2 right images
# Patient 155: 2 left, 2 right images
# Patient 156: 2 left, 2 right images
# Patient 157: 2 left, 2 right images
# Patient 158: 2 left, 2 right images
# Patient 159: 2 left, 2 right images
# Patient 160: 2 left, 2 right images
# Patient 161: 2 left, 2 right images
# Patient 162: 2 left, 2 right images
# Patient 163: 2 left, 2 right images
# Patient 164: 2 left, 2 right images
# Patient 165: 2 left, 2 right images
# Patient 166: 2 left, 2 right images
# Patient 167: 2 left, 2 right images
# Patient 168: 2 left, 2 right images
# Patient 169: 2 left, 2 right images
# Patient 170: 2 left, 2 right images
# Patient 171: 2 left, 2 right images
# Patient 172: 2 left, 2 right images
# Patient 173: 2 left, 2 right images
# Patient 174: 2 left, 2 right images
# Patient 175: 2 left, 2 right images
# Patient 176: 2 left, 2 right images
# Patient 177: 2 left, 2 right images
# Patient 178: 2 left, 2 right images
# Patient 179: 2 left, 2 right images
# Patient 180: 2 left, 2 right images
# Patient 181: 2 left, 2 right images
# Patient 182: 2 left, 2 right images
# Patient 183: 2 left, 2 right images
# Patient 184: 2 left, 2 right images
# Patient 185: 2 left, 2 right images
# Patient 186: 2 left, 2 right images
# Patient 187: 2 left, 2 right images
# Patient 188: 2 left, 2 right images
# Patient 189: 2 left, 2 right images
# Patient 190: 2 left, 2 right images
# Patient 191: 2 left, 2 right images
# Patient 192: 2 left, 2 right images
# Patient 193: 2 left, 2 right images
# Patient 194: 2 left, 2 right images
# Patient 195: 2 left, 2 right images
# Patient 196: 2 left, 2 right images
# Patient 197: 2 left, 2 right images
# Patient 198: 2 left, 2 right images
# Patient 199: 2 left, 2 right images
# Patient 200: 2 left, 2 right images
# Patient 201: 2 left, 2 right images
# Patient 202: 2 left, 2 right images
# Patient 203: 2 left, 2 right images
# Patient 204: 2 left, 2 right images
# Patient 205: 2 left, 2 right images
# Patient 206: 2 left, 2 right images
# Patient 207: 2 left, 2 right images
# Patient 208: 2 left, 2 right images
# Patient 209: 2 left, 2 right images
# Patient 210: 2 left, 2 right images
# Patient 211: 2 left, 2 right images
# Patient 212: 2 left, 2 right images
# Patient 213: 2 left, 2 right images
# Patient 214: 2 left, 2 right images
# Patient 215: 2 left, 2 right images
# Patient 216: 2 left, 2 right images
# Patient 217: 2 left, 2 right images
# Patient 218: 2 left, 2 right images
# Patient 219: 2 left, 2 right images
# Patient 220: 2 left, 2 right images
# Patient 221: 2 left, 2 right images
# Patient 222: 2 left, 2 right images
# Patient 223: 2 left, 2 right images
# Patient 224: 2 left, 2 right images
# Patient 225: 2 left, 2 right images
# Patient 226: 2 left, 2 right images
# Patient 227: 2 left, 2 right images
# Patient 228: 2 left, 2 right images
# Patient 229: 2 left, 2 right images
# Patient 230: 2 left, 2 right images
# Patient 231: 2 left, 2 right images
# Patient 232: 2 left, 2 right images
# Patient 233: 2 left, 2 right images
# Patient 234: 2 left, 2 right images
# Patient 235: 2 left, 2 right images
# Patient 236: 2 left, 2 right images
# Patient 237: 2 left, 2 right images
# Patient 238: 2 left, 2 right images
# Patient 239: 2 left, 2 right images
# Patient 240: 2 left, 2 right images
# Patient 241: 2 left, 2 right images
# Patient 242: 2 left, 2 right images
# Patient 243: 2 left, 2 right images
# Patient 244: 2 left, 2 right images
# Patient 245: 2 left, 2 right images
# Patient 246: 2 left, 2 right images
# Patient 247: 2 left, 2 right images
# Patient 248: 2 left, 2 right images
# Patient 249: 2 left, 2 right images
# Patient 250: 2 left, 2 right images
# Patient 251: 2 left, 2 right images
# Patient 252: 2 left, 2 right images
# Patient 253: 2 left, 2 right images
# Patient 254: 2 left, 2 right images
# Patient 255: 2 left, 2 right images
# Patient 256: 2 left, 2 right images
# Patient 257: 2 left, 2 right images
# Patient 258: 2 left, 2 right images
# Patient 259: 2 left, 2 right images
# Patient 260: 2 left, 2 right images
# Patient 261: 2 left, 2 right images
# Patient 262: 2 left, 2 right images
# Patient 263: 2 left, 2 right images
# Patient 264: 2 left, 2 right images
# Patient 265: 2 left, 2 right images
# Patient 266: 2 left, 2 right images
# Patient 267: 2 left, 2 right images
# Patient 268: 2 left, 2 right images
# Patient 269: 2 left, 2 right images
# Patient 270: 2 left, 2 right images
# Patient 271: 2 left, 2 right images
# Patient 272: 2 left, 2 right images
# Patient 273: 2 left, 2 right images
# Patient 274: 2 left, 2 right images
# Patient 275: 2 left, 2 right images
# Patient 276: 2 left, 2 right images
# Patient 277: 2 left, 2 right images
# Patient 278: 2 left, 2 right images
# Patient 279: 2 left, 2 right images
# Patient 280: 2 left, 2 right images
# Patient 281: 2 left, 2 right images
# Patient 282: 2 left, 2 right images
# Patient 283: 2 left, 2 right images
# Patient 284: 2 left, 2 right images
# Patient 285: 2 left, 2 right images
# Patient 286: 2 left, 2 right images
# Patient 287: 2 left, 2 right images
# Patient 288: 2 left, 2 right images
# Patient 289: 2 left, 2 right images
# Patient 290: 2 left, 2 right images
# Patient 291: 2 left, 2 right images
# Patient 292: 2 left, 2 right images
# Patient 293: 2 left, 2 right images
# Patient 294: 2 left, 2 right images
# Patient 295: 2 left, 2 right images
# Patient 296: 2 left, 2 right images
# Patient 297: 2 left, 2 right images
# Patient 298: 2 left, 2 right images
# Patient 299: 2 left, 2 right images
# Patient 300: 2 left, 2 right images
# Patient 301: 2 left, 2 right images
# Patient 302: 2 left, 2 right images
# Patient 303: 2 left, 2 right images
# Patient 304: 2 left, 2 right images
# Patient 305: 2 left, 2 right images
# Patient 306: 2 left, 2 right images
# Patient 307: 2 left, 2 right images
# Patient 308: 2 left, 2 right images
# Patient 309: 2 left, 2 right images
# Patient 310: 2 left, 2 right images
# Patient 311: 2 left, 2 right images
# Patient 312: 2 left, 2 right images
# Patient 313: 2 left, 2 right images
# Patient 314: 2 left, 2 right images
# Patient 315: 2 left, 2 right images
# Patient 316: 2 left, 2 right images
# Patient 317: 2 left, 2 right images
# Patient 318: 2 left, 2 right images
# Patient 319: 2 left, 2 right images
# Patient 320: 2 left, 2 right images
# Patient 321: 2 left, 2 right images
# Patient 322: 2 left, 2 right images
# Patient 323: 2 left, 2 right images
# Patient 324: 2 left, 2 right images
# Patient 325: 2 left, 2 right images
# Patient 326: 2 left, 2 right images
# Patient 327: 2 left, 2 right images
# Patient 328: 2 left, 2 right images
# Patient 329: 2 left, 2 right images
# Patient 330: 2 left, 2 right images
# Patient 331: 2 left, 2 right images
# Patient 332: 2 left, 2 right images
# Patient 333: 2 left, 2 right images
# Patient 334: 2 left, 2 right images
# Patient 335: 2 left, 2 right images
# Patient 336: 2 left, 2 right images
# Patient 337: 2 left, 2 right images
# Patient 338: 2 left, 2 right images
# Patient 339: 2 left, 2 right images
# Patient 340: 2 left, 2 right images
# Patient 341: 2 left, 2 right images
# Patient 342: 2 left, 2 right images
# Patient 343: 2 left, 2 right images
# Patient 344: 2 left, 2 right images
# Patient 345: 2 left, 2 right images
# Patient 346: 2 left, 2 right images
# Patient 347: 2 left, 2 right images
# Patient 348: 2 left, 2 right images
# Patient 349: 2 left, 2 right images
# Patient 350: 2 left, 2 right images
# Patient 351: 2 left, 2 right images
# Patient 352: 2 left, 2 right images
# Patient 353: 2 left, 2 right images
# Patient 354: 2 left, 2 right images
# Patient 355: 2 left, 2 right images
# Patient 356: 2 left, 2 right images
# Patient 357: 2 left, 2 right images
# Patient 358: 2 left, 2 right images
# Patient 359: 2 left, 2 right images
# Patient 360: 2 left, 2 right images
# Patient 361: 2 left, 2 right images
# Patient 362: 2 left, 2 right images
# Patient 363: 2 left, 2 right images
# Patient 364: 2 left, 2 right images
# Patient 365: 2 left, 2 right images
# Patient 366: 2 left, 2 right images
# Patient 367: 2 left, 2 right images
# Patient 368: 2 left, 2 right images
# Patient 369: 2 left, 2 right images
# Patient 370: 2 left, 2 right images
# Patient 371: 2 left, 2 right images
# Patient 372: 2 left, 2 right images
# Patient 373: 2 left, 2 right images
# Patient 374: 2 left, 2 right images
# Patient 375: 2 left, 2 right images
# Patient 376: 2 left, 2 right images
# Patient 377: 2 left, 2 right images
# Patient 378: 2 left, 2 right images
# Patient 379: 2 left, 2 right images
# Patient 380: 2 left, 2 right images
# Patient 381: 2 left, 2 right images
# Patient 382: 2 left, 2 right images
# Patient 383: 2 left, 2 right images
# Patient 384: 2 left, 2 right images
# Patient 385: 2 left, 2 right images
# Patient 386: 2 left, 2 right images
# Patient 387: 2 left, 2 right images
# Patient 388: 2 left, 2 right images
# Patient 389: 2 left, 2 right images
# Patient 390: 2 left, 2 right images
# Patient 391: 2 left, 2 right images
# Patient 392: 2 left, 2 right images
# Patient 393: 2 left, 2 right images
# Patient 394: 2 left, 2 right images
# Patient 395: 2 left, 2 right images
# Patient 396: 2 left, 2 right images
# Patient 397: 2 left, 2 right images
# Patient 398: 2 left, 2 right images
# Patient 399: 2 left, 2 right images
# Patient 400: 2 left, 2 right images
# Patient 401: 2 left, 2 right images
# Patient 402: 2 left, 2 right images
# Patient 403: 2 left, 2 right images
# Patient 404: 2 left, 2 right images
# Patient 405: 2 left, 2 right images
# Patient 406: 2 left, 2 right images
# Patient 407: 2 left, 2 right images
# Patient 408: 2 left, 2 right images
# Patient 409: 2 left, 2 right images
# Patient 410: 2 left, 2 right images
# Patient 411: 2 left, 2 right images
# Patient 412: 2 left, 2 right images
# Patient 413: 2 left, 2 right images
# Patient 414: 2 left, 2 right images
# Patient 415: 2 left, 2 right images
# Patient 416: 2 left, 2 right images
# Patient 417: 2 left, 2 right images
# Patient 418: 2 left, 2 right images
# Patient 419: 2 left, 2 right images
# Patient 420: 2 left, 2 right images
# Patient 421: 2 left, 2 right images
# Patient 422: 2 left, 2 right images
# Patient 423: 2 left, 2 right images
# Patient 424: 2 left, 2 right images
# Patient 425: 2 left, 2 right images
# Patient 426: 2 left, 2 right images
# Patient 427: 2 left, 2 right images
# Patient 428: 2 left, 2 right images
# Patient 429: 2 left, 2 right images
# Patient 430: 2 left, 2 right images
# Patient 431: 2 left, 2 right images
# Patient 432: 2 left, 2 right images
# Patient 433: 2 left, 2 right images
# Patient 434: 2 left, 2 right images
# Patient 435: 2 left, 2 right images
# Patient 436: 2 left, 2 right images
# Patient 437: 2 left, 2 right images
# Patient 438: 2 left, 2 right images
# Patient 439: 2 left, 2 right images
# Patient 440: 2 left, 2 right images
# Patient 441: 2 left, 2 right images
# Patient 442: 2 left, 2 right images
# Patient 443: 2 left, 2 right images
# Patient 444: 2 left, 2 right images
# Patient 445: 2 left, 2 right images
# Patient 446: 2 left, 2 right images
# Patient 447: 2 left, 2 right images
# Patient 448: 2 left, 2 right images
# Patient 449: 2 left, 2 right images
# Patient 450: 2 left, 2 right images
# Patient 451: 2 left, 2 right images
# Patient 452: 2 left, 2 right images
# Patient 453: 2 left, 2 right images
# Patient 454: 2 left, 2 right images
# Patient 455: 2 left, 2 right images
# Patient 456: 2 left, 2 right images
# Patient 457: 2 left, 2 right images
# Patient 458: 2 left, 2 right images
# Patient 459: 2 left, 2 right images
# Patient 460: 2 left, 2 right images
# Patient 461: 2 left, 2 right images
# Patient 462: 2 left, 2 right images
# Patient 463: 2 left, 2 right images
# Patient 464: 2 left, 2 right images
# Patient 465: 2 left, 2 right images
# Patient 466: 2 left, 2 right images
# Patient 467: 2 left, 2 right images
# Patient 468: 2 left, 2 right images
# Patient 469: 2 left, 2 right images
# Patient 470: 2 left, 2 right images
# Patient 471: 2 left, 2 right images
# Patient 472: 2 left, 2 right images
# Patient 473: 2 left, 2 right images
# Patient 474: 2 left, 2 right images
# Patient 475: 2 left, 2 right images
# Patient 476: 2 left, 2 right images
# Patient 477: 2 left, 2 right images
# Patient 478: 2 left, 2 right images
# Patient 479: 2 left, 2 right images
# Patient 480: 2 left, 2 right images
# Patient 481: 2 left, 2 right images
# Patient 482: 2 left, 2 right images
# Patient 483: 2 left, 2 right images
# Patient 484: 2 left, 2 right images
# Patient 485: 2 left, 2 right images
# Patient 486: 2 left, 2 right images
# Patient 487: 2 left, 2 right images
# Patient 488: 2 left, 2 right images
# Patient 489: 2 left, 2 right images
# Patient 490: 2 left, 2 right images
# Patient 491: 2 left, 2 right images
# Patient 492: 2 left, 2 right images
# Patient 493: 2 left, 2 right images
# Patient 494: 2 left, 2 right images
# Patient 495: 2 left, 2 right images
# Patient 496: 2 left, 2 right images
# Patient 497: 2 left, 2 right images
# Patient 498: 2 left, 2 right images
# Patient 499: 2 left, 2 right images
# Patient 500: 2 left, 2 right images
# Patient 501: 2 left, 2 right images
# Patient 502: 2 left, 2 right images
# Patient 503: 2 left, 2 right images
# Patient 504: 2 left, 2 right images
# Patient 505: 2 left, 2 right images
# Patient 506: 2 left, 2 right images
# Patient 507: 2 left, 2 right images
# Patient 508: 2 left, 2 right images
# Patient 509: 2 left, 2 right images
# Patient 510: 2 left, 2 right images
# Patient 511: 2 left, 2 right images
# Patient 512: 2 left, 2 right images
# Patient 513: 2 left, 2 right images
# Patient 514: 2 left, 2 right images
# Patient 515: 2 left, 2 right images
# Patient 516: 2 left, 2 right images
# Patient 517: 2 left, 2 right images
# Patient 518: 2 left, 2 right images
# Patient 519: 2 left, 2 right images
# Patient 520: 2 left, 2 right images
# Patient 521: 2 left, 2 right images
# Patient 522: 2 left, 2 right images
# Patient 523: 2 left, 2 right images
# Patient 524: 2 left, 2 right images
# Patient 525: 2 left, 2 right images
# Patient 526: 2 left, 2 right images
# Patient 527: 2 left, 2 right images
# Patient 528: 2 left, 2 right images
# Patient 529: 2 left, 2 right images
# Patient 530: 2 left, 2 right images
# Patient 531: 2 left, 2 right images
# Patient 532: 2 left, 2 right images
# Patient 533: 2 left, 2 right images
# Patient 534: 2 left, 2 right images
# Patient 535: 2 left, 2 right images
# Patient 536: 2 left, 2 right images
# Patient 537: 2 left, 2 right images
# Patient 538: 2 left, 2 right images
# Patient 539: 2 left, 2 right images
# Patient 540: 2 left, 2 right images
# Patient 541: 2 left, 2 right images
# Patient 542: 2 left, 2 right images
# Patient 543: 2 left, 2 right images
# Patient 544: 2 left, 2 right images
# Patient 545: 2 left, 2 right images
# Patient 546: 2 left, 2 right images
# Patient 547: 2 left, 2 right images
# Patient 548: 2 left, 2 right images
# Patient 549: 2 left, 2 right images
# Patient 550: 2 left, 2 right images
# Patient 551: 2 left, 2 right images
# Patient 552: 2 left, 2 right images
# Patient 553: 2 left, 2 right images
# Patient 554: 2 left, 2 right images
# Patient 555: 2 left, 2 right images
# Patient 556: 2 left, 2 right images
# Patient 557: 2 left, 2 right images
# Patient 558: 2 left, 2 right images
# Patient 559: 2 left, 2 right images
# Patient 560: 2 left, 2 right images
# Patient 561: 2 left, 2 right images
# Patient 562: 2 left, 2 right images
# Patient 563: 2 left, 2 right images
# Patient 564: 2 left, 2 right images
# Patient 565: 2 left, 2 right images
# Patient 566: 2 left, 2 right images
# Patient 567: 2 left, 2 right images
# Patient 568: 2 left, 2 right images
# Patient 569: 2 left, 2 right images
# Patient 570: 2 left, 2 right images
# Patient 571: 2 left, 2 right images
# Patient 572: 2 left, 2 right images
# Patient 573: 2 left, 2 right images
# Patient 574: 2 left, 2 right images
# Patient 575: 2 left, 2 right images
# Patient 576: 2 left, 2 right images
# Patient 577: 2 left, 2 right images
# Patient 578: 2 left, 2 right images
# Patient 579: 2 left, 2 right images
# Patient 580: 2 left, 2 right images
# Patient 581: 2 left, 2 right images
# Patient 582: 2 left, 2 right images
# Patient 583: 2 left, 2 right images
# Patient 584: 2 left, 2 right images
# Patient 585: 2 left, 2 right images
# Patient 586: 2 left, 2 right images
# Patient 587: 2 left, 2 right images
# Patient 588: 2 left, 2 right images
# Patient 589: 2 left, 2 right images
# Patient 590: 2 left, 2 right images
# Patient 591: 2 left, 2 right images
# Patient 592: 2 left, 2 right images
# Patient 593: 2 left, 2 right images
# Patient 594: 2 left, 2 right images
# Patient 595: 2 left, 2 right images
# Patient 596: 2 left, 2 right images
# Patient 597: 2 left, 2 right images
# Patient 598: 2 left, 2 right images
# Patient 599: 2 left, 2 right images
# Patient 600: 2 left, 2 right images
# Patient 601: 2 left, 2 right images
# Patient 602: 2 left, 2 right images
# Patient 603: 2 left, 2 right images
# Patient 604: 2 left, 2 right images
# Patient 605: 2 left, 2 right images
# Patient 606: 2 left, 2 right images
# Patient 607: 2 left, 2 right images
# Patient 608: 2 left, 2 right images
# Patient 609: 2 left, 2 right images
# Patient 610: 2 left, 2 right images
# Patient 611: 2 left, 2 right images
# Patient 612: 2 left, 2 right images
# Patient 613: 2 left, 2 right images
# Patient 614: 2 left, 2 right images
# Patient 615: 2 left, 2 right images
# Patient 616: 2 left, 2 right images
# Patient 617: 2 left, 2 right images
# Patient 618: 2 left, 2 right images
# Patient 619: 2 left, 2 right images
# Patient 620: 2 left, 2 right images
# Patient 621: 2 left, 2 right images
# Patient 622: 2 left, 2 right images
# Patient 623: 2 left, 2 right images
# Patient 624: 2 left, 2 right images
# Patient 625: 2 left, 2 right images
# Patient 626: 2 left, 2 right images
# Patient 627: 2 left, 2 right images
# Patient 628: 2 left, 2 right images
# Patient 629: 2 left, 2 right images
# Patient 630: 2 left, 2 right images
# Patient 631: 2 left, 2 right images
# Patient 632: 2 left, 2 right images
# Patient 633: 2 left, 2 right images
# Patient 634: 2 left, 2 right images
# Patient 635: 2 left, 2 right images
# Patient 636: 2 left, 2 right images
# Patient 637: 2 left, 2 right images
# Patient 638: 2 left, 2 right images
# Patient 639: 2 left, 2 right images
# Patient 640: 2 left, 2 right images
# Patient 641: 2 left, 2 right images
# Patient 642: 2 left, 2 right images
# Patient 643: 2 left, 2 right images
# Patient 644: 2 left, 2 right images
# Patient 645: 2 left, 2 right images
# Patient 646: 2 left, 2 right images
# Patient 647: 2 left, 2 right images
# Patient 648: 2 left, 2 right images
# Patient 649: 2 left, 2 right images
# Patient 650: 2 left, 2 right images
# Patient 651: 2 left, 2 right images
# Patient 652: 2 left, 2 right images
# Patient 653: 2 left, 2 right images
# Patient 654: 2 left, 2 right images
# Patient 655: 2 left, 2 right images
# Patient 656: 2 left, 2 right images
# Patient 657: 2 left, 2 right images
# Patient 658: 2 left, 2 right images
# Patient 659: 2 left, 2 right images
# Patient 660: 2 left, 2 right images
# Patient 661: 2 left, 2 right images
# Patient 662: 2 left, 2 right images
# Patient 663: 2 left, 2 right images
# Patient 664: 2 left, 2 right images
# Patient 665: 2 left, 2 right images
# Patient 666: 2 left, 2 right images
# Patient 667: 2 left, 2 right images
# Patient 668: 2 left, 2 right images
# Patient 669: 2 left, 2 right images
# Patient 670: 2 left, 2 right images
# Patient 671: 2 left, 2 right images
# Patient 672: 2 left, 2 right images
# Patient 673: 2 left, 2 right images
# Patient 674: 2 left, 2 right images
# Patient 675: 2 left, 2 right images
# Patient 676: 2 left, 2 right images
# Patient 677: 2 left, 2 right images
# Patient 678: 2 left, 2 right images
# Patient 679: 2 left, 2 right images
# Patient 680: 2 left, 2 right images
# Patient 681: 2 left, 2 right images
# Patient 682: 2 left, 2 right images
# Patient 683: 2 left, 2 right images
# Patient 684: 2 left, 2 right images
# Patient 685: 2 left, 2 right images
# Patient 686: 2 left, 2 right images
# Patient 687: 2 left, 2 right images
# Patient 688: 2 left, 2 right images
# Patient 689: 2 left, 2 right images
# Patient 690: 2 left, 2 right images
# Patient 691: 2 left, 2 right images
# Patient 692: 2 left, 2 right images
# Patient 693: 2 left, 2 right images
# Patient 694: 2 left, 2 right images
# Patient 695: 2 left, 2 right images
# Patient 696: 2 left, 2 right images
# Patient 697: 2 left, 2 right images
# Patient 698: 2 left, 2 right images
# Patient 699: 2 left, 2 right images
# Patient 700: 2 left, 2 right images
# Patient 701: 2 left, 2 right images
# Patient 702: 2 left, 2 right images
# Patient 703: 2 left, 2 right images
# Patient 704: 2 left, 2 right images
# Patient 705: 2 left, 2 right images
# Patient 706: 2 left, 2 right images
# Patient 707: 2 left, 2 right images
# Patient 708: 2 left, 2 right images
# Patient 709: 2 left, 2 right images
# Patient 710: 2 left, 2 right images
# Patient 711: 2 left, 2 right images
# Patient 712: 2 left, 2 right images
# Patient 713: 2 left, 2 right images
# Patient 714: 2 left, 2 right images
# Patient 715: 2 left, 2 right images
# Patient 716: 2 left, 2 right images
# Patient 717: 2 left, 2 right images
# Patient 718: 2 left, 2 right images
# Patient 719: 2 left, 2 right images
# Patient 720: 2 left, 2 right images
# Patient 721: 2 left, 2 right images
# Patient 722: 2 left, 2 right images
# Patient 723: 2 left, 2 right images
# Patient 724: 2 left, 2 right images
# Patient 725: 2 left, 2 right images
# Patient 726: 2 left, 2 right images
# Patient 727: 2 left, 2 right images
# Patient 728: 2 left, 2 right images
# Patient 729: 2 left, 2 right images
# Patient 730: 2 left, 2 right images
# Patient 731: 2 left, 2 right images
# Patient 732: 2 left, 2 right images
# Patient 733: 2 left, 2 right images
# Patient 734: 2 left, 2 right images
# Patient 735: 2 left, 2 right images
# Patient 736: 2 left, 2 right images
# Patient 737: 2 left, 2 right images
# Patient 738: 2 left, 2 right images
# Patient 739: 2 left, 2 right images
# Patient 740: 2 left, 2 right images
# Patient 741: 2 left, 2 right images
# Patient 742: 2 left, 2 right images
# Patient 743: 2 left, 2 right images
# Patient 744: 2 left, 2 right images
# Patient 745: 2 left, 2 right images
# Patient 746: 2 left, 2 right images
# Patient 747: 2 left, 2 right images
# Patient 748: 2 left, 2 right images
# Patient 749: 2 left, 2 right images
# Patient 750: 2 left, 2 right images
# Patient 751: 2 left, 2 right images
# Patient 752: 2 left, 2 right images
# Patient 753: 2 left, 2 right images
# Patient 754: 2 left, 2 right images
# Patient 755: 2 left, 2 right images
# Patient 756: 2 left, 2 right images
# Patient 757: 2 left, 2 right images
# Patient 758: 2 left, 2 right images
# Patient 759: 2 left, 2 right images
# Patient 760: 2 left, 2 right images
# Patient 761: 2 left, 2 right images
# Patient 762: 2 left, 2 right images
# Patient 763: 2 left, 2 right images
# Patient 764: 2 left, 2 right images
# Patient 765: 2 left, 2 right images
# Patient 766: 2 left, 2 right images
# Patient 767: 2 left, 2 right images
# Patient 768: 2 left, 2 right images
# Patient 769: 2 left, 2 right images
# Patient 770: 2 left, 2 right images
# Patient 771: 2 left, 2 right images
# Patient 772: 2 left, 2 right images
# Patient 773: 2 left, 2 right images
# Patient 774: 2 left, 2 right images
# Patient 775: 2 left, 2 right images
# Patient 776: 2 left, 2 right images
# Patient 777: 2 left, 2 right images
# Patient 778: 2 left, 2 right images
# Patient 779: 2 left, 2 right images
# Patient 780: 2 left, 2 right images
# Patient 781: 2 left, 2 right images
# Patient 782: 2 left, 2 right images
# Patient 783: 2 left, 2 right images
# Patient 784: 2 left, 2 right images
# Patient 785: 2 left, 2 right images
# Patient 786: 2 left, 2 right images
# Patient 787: 2 left, 2 right images
# Patient 788: 2 left, 2 right images
# Patient 789: 2 left, 2 right images
# Patient 790: 2 left, 2 right images
# Patient 791: 2 left, 2 right images
# Patient 792: 2 left, 2 right images
# Patient 793: 2 left, 2 right images
# Patient 794: 2 left, 2 right images
# Patient 795: 2 left, 2 right images
# Patient 796: 2 left, 2 right images
# Patient 797: 2 left, 2 right images
# Patient 798: 2 left, 2 right images
# Patient 799: 2 left, 2 right images
# Patient 800: 2 left, 2 right images
# Patient 801: 2 left, 2 right images
# Patient 802: 2 left, 2 right images
# Patient 803: 2 left, 2 right images
# Patient 804: 2 left, 2 right images
# Patient 805: 2 left, 2 right images
# Patient 806: 2 left, 2 right images
# Patient 807: 2 left, 2 right images
# Patient 808: 2 left, 2 right images
# Patient 809: 2 left, 2 right images
# Patient 810: 2 left, 2 right images
# Patient 811: 2 left, 2 right images
# Patient 812: 2 left, 2 right images
# Patient 813: 2 left, 2 right images
# Patient 814: 2 left, 2 right images
# Patient 815: 2 left, 2 right images
# Patient 816: 2 left, 2 right images
# Patient 817: 2 left, 2 right images
# Patient 818: 2 left, 2 right images
# Patient 819: 2 left, 2 right images
# Patient 820: 2 left, 2 right images
# Patient 821: 2 left, 2 right images
# Patient 822: 2 left, 2 right images
# Patient 823: 2 left, 2 right images
# Patient 824: 2 left, 2 right images
# Patient 825: 2 left, 2 right images
# Patient 826: 2 left, 2 right images
# Patient 827: 2 left, 2 right images
# Patient 828: 2 left, 2 right images
# Patient 829: 2 left, 2 right images
# Patient 830: 2 left, 2 right images
# Patient 831: 2 left, 2 right images
# Patient 832: 2 left, 2 right images
# Patient 833: 2 left, 2 right images
# Patient 834: 2 left, 2 right images
# Patient 835: 2 left, 2 right images
# Patient 836: 2 left, 2 right images
# Patient 837: 2 left, 2 right images
# Patient 838: 2 left, 2 right images
# Patient 839: 2 left, 2 right images
# Patient 840: 2 left, 2 right images
# Patient 841: 2 left, 2 right images
# Patient 842: 2 left, 2 right images
# Patient 843: 2 left, 2 right images
# Patient 844: 2 left, 2 right images
# Patient 845: 2 left, 2 right images
# Patient 846: 2 left, 2 right images
# Patient 847: 2 left, 2 right images
# Patient 848: 2 left, 2 right images
# Patient 849: 2 left, 2 right images
# Patient 850: 2 left, 2 right images
# Patient 851: 2 left, 2 right images
# Patient 852: 2 left, 2 right images
# Patient 853: 2 left, 2 right images
# Patient 854: 2 left, 2 right images
# Patient 855: 2 left, 2 right images
# Patient 856: 2 left, 2 right images
# Patient 857: 2 left, 2 right images
# Patient 858: 2 left, 2 right images
# Patient 859: 2 left, 2 right images
# Patient 860: 2 left, 2 right images
# Patient 861: 2 left, 2 right images
# Patient 862: 2 left, 2 right images
# Patient 863: 2 left, 2 right images
# Patient 864: 2 left, 2 right images
# Patient 865: 2 left, 2 right images
# Patient 866: 2 left, 2 right images
# Patient 867: 2 left, 2 right images
# Patient 868: 2 left, 2 right images
# Patient 869: 2 left, 2 right images
# Patient 870: 2 left, 2 right images
# Patient 871: 2 left, 2 right images
# Patient 872: 2 left, 2 right images
# Patient 873: 2 left, 2 right images
# Patient 874: 2 left, 2 right images
# Patient 875: 2 left, 2 right images
# Patient 876: 2 left, 2 right images
# Patient 877: 2 left, 2 right images
# Patient 878: 2 left, 2 right images
# Patient 879: 2 left, 2 right images
# Patient 880: 2 left, 2 right images
# Patient 881: 2 left, 2 right images
# Patient 882: 2 left, 2 right images
# Patient 883: 2 left, 2 right images
# Patient 884: 2 left, 2 right images
# Patient 885: 2 left, 2 right images
# Patient 886: 2 left, 2 right images
# Patient 887: 2 left, 2 right images
# Patient 888: 2 left, 2 right images
# Patient 889: 2 left, 2 right images
# Patient 890: 2 left, 2 right images
# Patient 891: 2 left, 2 right images
# Patient 892: 2 left, 2 right images
# Patient 893: 2 left, 2 right images
# Patient 894: 2 left, 2 right images
# Patient 895: 2 left, 2 right images
# Patient 896: 2 left, 2 right images
# Patient 897: 2 left, 2 right images
# Patient 898: 2 left, 2 right images
# Patient 899: 2 left, 2 right images
# Patient 900: 2 left, 2 right images
# Patient 901: 2 left, 2 right images
# Patient 902: 2 left, 2 right images
# Patient 903: 2 left, 2 right images
# Patient 904: 2 left, 2 right images
# Patient 905: 2 left, 2 right images
# Patient 906: 2 left, 2 right images
# Patient 907: 2 left, 2 right images
# Patient 908: 2 left, 2 right images
# Patient 909: 2 left, 2 right images
# Patient 910: 2 left, 2 right images
# Patient 911: 2 left, 2 right images
# Patient 912: 2 left, 2 right images
# Patient 913: 2 left, 2 right images
# Patient 914: 2 left, 2 right images
# Patient 915: 2 left, 2 right images
# Patient 916: 2 left, 2 right images
# Patient 917: 2 left, 2 right images
# Patient 918: 2 left, 2 right images
# Patient 919: 2 left, 2 right images
# Patient 920: 2 left, 2 right images
# Patient 921: 2 left, 2 right images
# Patient 922: 2 left, 2 right images
# Patient 923: 2 left, 2 right images
# Patient 924: 2 left, 2 right images
# Patient 925: 2 left, 2 right images
# Patient 926: 2 left, 2 right images
# Patient 927: 2 left, 2 right images
# Patient 928: 2 left, 2 right images
# Patient 929: 2 left, 2 right images
# Patient 930: 2 left, 2 right images
# Patient 931: 2 left, 2 right images
# Patient 932: 2 left, 2 right images
# Patient 933: 2 left, 2 right images
# Patient 934: 2 left, 2 right images
# Patient 935: 2 left, 2 right images
# Patient 936: 2 left, 2 right images
# Patient 937: 2 left, 2 right images
# Patient 938: 2 left, 2 right images
# Patient 939: 2 left, 2 right images
# Patient 940: 2 left, 2 right images
# Patient 941: 2 left, 2 right images
# Patient 942: 2 left, 2 right images
# Patient 943: 2 left, 2 right images
# Patient 944: 2 left, 2 right images
# Patient 945: 2 left, 2 right images
# Patient 946: 2 left, 2 right images
# Patient 947: 2 left, 2 right images
# Patient 948: 2 left, 2 right images
# Patient 949: 2 left, 2 right images
# Patient 950: 2 left, 2 right images
# Patient 951: 2 left, 2 right images
# Patient 952: 2 left, 2 right images
# Patient 953: 2 left, 2 right images
# Patient 954: 2 left, 2 right images
# Patient 955: 2 left, 2 right images
# Patient 956: 2 left, 2 right images
# Patient 957: 2 left, 2 right images
# Patient 958: 2 left, 2 right images
# Patient 959: 2 left, 2 right images
# Patient 960: 2 left, 2 right images
# Patient 961: 2 left, 2 right images
# Patient 962: 2 left, 2 right images
# Patient 963: 2 left, 2 right images
# Patient 964: 2 left, 2 right images
# Patient 965: 2 left, 2 right images
# Patient 966: 2 left, 2 right images
# Patient 967: 2 left, 2 right images
# Patient 968: 2 left, 2 right images
# Patient 969: 2 left, 2 right images
# Patient 970: 2 left, 2 right images
# Patient 971: 2 left, 2 right images
# Patient 972: 2 left, 2 right images
# Patient 973: 2 left, 2 right images
# Patient 974: 2 left, 2 right images
# Patient 975: 2 left, 2 right images
# Patient 976: 2 left, 2 right images
# Patient 977: 2 left, 2 right images
# Patient 978: 2 left, 2 right images
# Patient 979: 2 left, 2 right images
# Patient 980: 2 left, 2 right images
# Patient 981: 2 left, 2 right images
# Patient 982: 2 left, 2 right images
# Patient 983: 2 left, 2 right images
# Patient 984: 2 left, 2 right images
# Patient 985: 2 left, 2 right images
# Patient 986: 2 left, 2 right images
# Patient 987: 2 left, 2 right images
# Patient 988: 2 left, 2 right images
# Patient 989: 2 left, 2 right images
# Patient 990: 2 left, 2 right images
# Patient 991: 2 left, 2 right images
# Patient 992: 2 left, 2 right images
# Patient 993: 2 left, 2 right images
# Patient 994: 2 left, 2 right images
# Patient 995: 2 left, 2 right images
# Patient 996: 2 left, 2 right images
# Patient 997: 2 left, 2 right images
# Patient 998: 2 left, 2 right images
# Patient 999: 2 left, 2 right images
# Patient 1000: 2 left, 2 right images
# Patient 1001: 2 left, 2 right images
# Patient 1002: 2 left, 2 right images
# Patient 1003: 2 left, 2 right images
# Patient 1004: 2 left, 2 right images
# Patient 1005: 2 left, 2 right images
# Patient 1006: 2 left, 2 right images
# Patient 1007: 2 left, 2 right images
# Patient 1008: 2 left, 2 right images
# Patient 1009: 2 left, 2 right images
# Patient 1010: 2 left, 2 right images
# Patient 1011: 2 left, 2 right images
# Patient 1012: 2 left, 2 right images
# Patient 1013: 2 left, 2 right images
# Patient 1014: 2 left, 2 right images
# Patient 1015: 2 left, 2 right images
# Patient 1016: 2 left, 2 right images
# Patient 1017: 2 left, 2 right images
# Patient 1018: 2 left, 2 right images
# Patient 1019: 2 left, 2 right images
# Patient 1020: 2 left, 2 right images
# Patient 1021: 2 left, 2 right images
# Patient 1022: 2 left, 2 right images
# Patient 1023: 2 left, 2 right images
# Patient 1024: 2 left, 2 right images
# Patient 1025: 2 left, 2 right images
# Patient 1026: 2 left, 2 right images
# Patient 1027: 2 left, 2 right images
# Patient 1028: 2 left, 2 right images
# Patient 1029: 2 left, 2 right images
# Patient 1030: 2 left, 2 right images
# Patient 1031: 2 left, 2 right images
# Patient 1032: 2 left, 2 right images
# Patient 1033: 2 left, 2 right images
# Patient 1034: 2 left, 2 right images
# Patient 1035: 2 left, 2 right images
# Patient 1036: 2 left, 2 right images
# Patient 1037: 2 left, 2 right images
# Patient 1038: 2 left, 2 right images
# Patient 1039: 2 left, 2 right images
# Patient 1040: 2 left, 2 right images
# Patient 1041: 2 left, 2 right images
# Patient 1042: 2 left, 2 right images
# Patient 1043: 2 left, 2 right images
# Patient 1044: 2 left, 2 right images
# Patient 1045: 2 left, 2 right images
# Patient 1046: 2 left, 2 right images
# Patient 1047: 2 left, 2 right images
# Patient 1048: 2 left, 2 right images
# Patient 1049: 2 left, 2 right images
# Patient 1050: 2 left, 2 right images
# Patient 1051: 2 left, 2 right images
# Patient 1052: 2 left, 2 right images
# Patient 1053: 2 left, 2 right images
# Patient 1054: 2 left, 2 right images
# Patient 1055: 2 left, 2 right images
# Patient 1056: 2 left, 2 right images
# Patient 1057: 2 left, 2 right images
# Patient 1058: 2 left, 2 right images
# Patient 1059: 2 left, 2 right images
# Patient 1060: 2 left, 2 right images
# Patient 1061: 2 left, 2 right images
# Patient 1062: 2 left, 2 right images
# Patient 1063: 2 left, 2 right images
# Patient 1064: 2 left, 2 right images
# Patient 1065: 2 left, 2 right images
# Patient 1066: 2 left, 2 right images
# Patient 1067: 2 left, 2 right images
# Patient 1068: 2 left, 2 right images
# Patient 1069: 2 left, 2 right images
# Patient 1070: 2 left, 2 right images
# Patient 1071: 2 left, 2 right images
# Patient 1072: 2 left, 2 right images
# Patient 1073: 2 left, 2 right images
# Patient 1074: 2 left, 2 right images
# Patient 1075: 2 left, 2 right images
# Patient 1076: 2 left, 2 right images
# Patient 1077: 2 left, 2 right images
# Patient 1078: 2 left, 2 right images
# Patient 1079: 2 left, 2 right images
# Patient 1080: 2 left, 2 right images
# Patient 1081: 2 left, 2 right images
# Patient 1082: 2 left, 2 right images
# Patient 1083: 2 left, 2 right images
# Patient 1084: 2 left, 2 right images
# Patient 1085: 2 left, 2 right images
# Patient 1086: 2 left, 2 right images
# Patient 1087: 2 left, 2 right images
# Patient 1088: 2 left, 2 right images
# Patient 1089: 2 left, 2 right images
# Patient 1090: 2 left, 2 right images
# Patient 1091: 2 left, 2 right images
# Patient 1092: 2 left, 2 right images
# Patient 1093: 2 left, 2 right images
# Patient 1094: 2 left, 2 right images
# Patient 1095: 2 left, 2 right images
# Patient 1096: 2 left, 2 right images
# Patient 1097: 2 left, 2 right images
# Patient 1098: 2 left, 2 right images
# Patient 1099: 2 left, 2 right images
# Patient 1100: 2 left, 2 right images
# Patient 1101: 2 left, 2 right images
# Patient 1102: 2 left, 2 right images
# Patient 1103: 2 left, 2 right images
# Patient 1104: 2 left, 2 right images
# Patient 1105: 2 left, 2 right images
# Patient 1106: 2 left, 2 right images
# Patient 1107: 2 left, 2 right images
# Patient 1108: 2 left, 2 right images
# Patient 1109: 2 left, 2 right images
# Patient 1110: 2 left, 2 right images
# Patient 1111: 2 left, 2 right images
# Patient 1112: 2 left, 2 right images
# Patient 1113: 2 left, 2 right images
# Patient 1114: 2 left, 2 right images
# Patient 1115: 2 left, 2 right images
# Patient 1116: 2 left, 2 right images
# Patient 1117: 2 left, 2 right images
# Patient 1118: 2 left, 2 right images
# Patient 1119: 2 left, 2 right images
# Patient 1120: 2 left, 2 right images
# Patient 1121: 2 left, 2 right images
# Patient 1122: 2 left, 2 right images
# Patient 1123: 2 left, 2 right images
# Patient 1124: 2 left, 2 right images
# Patient 1125: 2 left, 2 right images
# Patient 1126: 2 left, 2 right images
# Patient 1127: 2 left, 2 right images
# Patient 1128: 2 left, 2 right images
# Patient 1129: 2 left, 2 right images
# Patient 1130: 2 left, 2 right images
# Patient 1131: 2 left, 2 right images
# Patient 1132: 2 left, 2 right images
# Patient 1133: 2 left, 2 right images
# Patient 1134: 2 left, 2 right images
# Patient 1135: 2 left, 2 right images
# Patient 1136: 2 left, 2 right images
# Patient 1137: 2 left, 2 right images
# Patient 1138: 2 left, 2 right images
# Patient 1139: 2 left, 2 right images
# Patient 1140: 2 left, 2 right images
# Patient 1141: 2 left, 2 right images
# Patient 1142: 2 left, 2 right images
# Patient 1143: 2 left, 2 right images
# Patient 1144: 2 left, 2 right images
# Patient 1145: 2 left, 2 right images
# Patient 1146: 2 left, 2 right images
# Patient 1147: 2 left, 2 right images
# Patient 1148: 2 left, 2 right images
# Patient 1149: 2 left, 2 right images
# Patient 1150: 2 left, 2 right images
# Patient 1151: 2 left, 2 right images
# Patient 1152: 2 left, 2 right images
# Patient 1153: 2 left, 2 right images
# Patient 1154: 2 left, 2 right images
# Patient 1155: 2 left, 2 right images
# Patient 1156: 2 left, 2 right images
# Patient 1157: 2 left, 2 right images
# Patient 1158: 2 left, 2 right images
# Patient 1159: 2 left, 2 right images
# Patient 1160: 2 left, 2 right images
# Patient 1161: 2 left, 2 right images
# Patient 1162: 2 left, 2 right images
# Patient 1163: 2 left, 2 right images
# Patient 1164: 2 left, 2 right images
# Patient 1165: 2 left, 2 right images
# Patient 1166: 2 left, 2 right images
# Patient 1167: 2 left, 2 right images
# Patient 1168: 2 left, 2 right images
# Patient 1169: 2 left, 2 right images
# Patient 1170: 2 left, 2 right images
# Patient 1171: 2 left, 2 right images
# Patient 1172: 2 left, 2 right images
# Patient 1173: 2 left, 2 right images
# Patient 1174: 2 left, 2 right images
# Patient 1175: 2 left, 2 right images
# Patient 1176: 2 left, 2 right images
# Patient 1177: 2 left, 2 right images
# Patient 1178: 2 left, 2 right images
# Patient 1179: 2 left, 2 right images
# Patient 1180: 2 left, 2 right images
# Patient 1181: 2 left, 2 right images
# Patient 1182: 2 left, 2 right images
# Patient 1183: 2 left, 2 right images
# Patient 1184: 2 left, 2 right images
# Patient 1185: 2 left, 2 right images
# Patient 1186: 2 left, 2 right images
# Patient 1187: 2 left, 2 right images
# Patient 1188: 2 left, 2 right images
# Patient 1189: 2 left, 2 right images
# Patient 1190: 2 left, 2 right images
# Patient 1191: 2 left, 2 right images
# Patient 1192: 2 left, 2 right images
# Patient 1193: 2 left, 2 right images
# Patient 1194: 2 left, 2 right images
# Patient 1195: 2 left, 2 right images
# Patient 1196: 2 left, 2 right images
# Patient 1197: 2 left, 2 right images
# Patient 1198: 2 left, 2 right images
# Patient 1199: 2 left, 2 right images
# Patient 1200: 2 left, 2 right images
# Patient 1201: 2 left, 2 right images
# Patient 1202: 2 left, 2 right images
# Patient 1203: 2 left, 2 right images
# Patient 1204: 2 left, 2 right images
# Patient 1205: 2 left, 2 right images
# Patient 1206: 2 left, 2 right images
# Patient 1207: 2 left, 2 right images
# Patient 1208: 2 left, 2 right images
# Patient 1209: 2 left, 2 right images
# Patient 1210: 2 left, 2 right images
# Patient 1211: 2 left, 2 right images
# Patient 1212: 2 left, 2 right images
# Patient 1213: 2 left, 2 right images
# Patient 1214: 2 left, 2 right images
# Patient 1215: 2 left, 2 right images
# Patient 1216: 2 left, 2 right images
# Patient 1217: 2 left, 2 right images
# Patient 1218: 2 left, 2 right images
# Patient 1219: 2 left, 2 right images
# Patient 1220: 2 left, 2 right images
# Patient 1221: 2 left, 2 right images
# Patient 1222: 2 left, 2 right images
# Patient 1223: 2 left, 2 right images
# Patient 1224: 2 left, 2 right images
# Patient 1225: 2 left, 2 right images
# Patient 1226: 2 left, 2 right images
# Patient 1227: 2 left, 2 right images
# Patient 1228: 2 left, 2 right images
# Patient 1229: 2 left, 2 right images
# Patient 1230: 2 left, 2 right images
# Patient 1231: 2 left, 2 right images
# Patient 1232: 2 left, 2 right images
# Patient 1233: 2 left, 2 right images
# Patient 1234: 2 left, 2 right images
# Patient 1235: 2 left, 2 right images
# Patient 1236: 2 left, 2 right images
# Patient 1237: 2 left, 2 right images
# Patient 1238: 2 left, 2 right images
# Patient 1239: 2 left, 2 right images
# Patient 1240: 2 left, 2 right images
# Patient 1241: 2 left, 2 right images
# Patient 1242: 2 left, 2 right images
# Patient 1243: 2 left, 2 right images
# Patient 1244: 2 left, 2 right images
# Patient 1245: 2 left, 2 right images
# Patient 1246: 2 left, 2 right images
# Patient 1247: 2 left, 2 right images
# Patient 1248: 2 left, 2 right images
# Patient 1249: 2 left, 2 right images
# Patient 1250: 2 left, 2 right images
# Patient 1251: 2 left, 2 right images
# Patient 1252: 2 left, 2 right images
# Patient 1253: 2 left, 2 right images
# Patient 1254: 2 left, 2 right images
# Patient 1255: 2 left, 2 right images
# Patient 1256: 2 left, 2 right images
# Patient 1257: 2 left, 2 right images
# Patient 1258: 2 left, 2 right images
# Patient 1259: 2 left, 2 right images
# Patient 1260: 2 left, 2 right images
# Patient 1261: 2 left, 2 right images
# Patient 1262: 2 left, 2 right images
# Patient 1263: 2 left, 2 right images
# Patient 1264: 2 left, 2 right images
# Patient 1265: 2 left, 2 right images
# Patient 1266: 2 left, 2 right images
# Patient 1267: 2 left, 2 right images
# Patient 1268: 2 left, 2 right images
# Patient 1269: 2 left, 2 right images
# Patient 1270: 2 left, 2 right images
# Patient 1271: 2 left, 2 right images
# Patient 1272: 2 left, 2 right images
# Patient 1273: 2 left, 2 right images
# Patient 1274: 2 left, 2 right images
# Patient 1275: 2 left, 2 right images
# Patient 1276: 2 left, 2 right images
# Patient 1277: 2 left, 2 right images
# Patient 1278: 2 left, 2 right images
# Patient 1279: 2 left, 2 right images
# Patient 1280: 2 left, 2 right images
# Patient 1281: 2 left, 2 right images
# Patient 1282: 2 left, 2 right images
# Patient 1283: 2 left, 2 right images
# Patient 1284: 2 left, 2 right images
# Patient 1285: 2 left, 2 right images
# Patient 1286: 2 left, 2 right images
# Patient 1287: 2 left, 2 right images
# Patient 1288: 2 left, 2 right images
# Patient 1289: 2 left, 2 right images
# Patient 1290: 2 left, 2 right images
# Patient 1291: 2 left, 2 right images
# Patient 1292: 2 left, 2 right images
# Patient 1293: 2 left, 2 right images
# Patient 1294: 2 left, 2 right images
# Patient 1295: 2 left, 2 right images
# Patient 1296: 2 left, 2 right images
# Patient 1297: 2 left, 2 right images
# Patient 1298: 2 left, 2 right images
# Patient 1299: 2 left, 2 right images
# Patient 1300: 2 left, 2 right images
# Patient 1301: 2 left, 2 right images
# Patient 1302: 2 left, 2 right images
# Patient 1303: 2 left, 2 right images
# Patient 1304: 2 left, 2 right images
# Patient 1305: 2 left, 2 right images
# Patient 1306: 2 left, 2 right images
# Patient 1307: 2 left, 2 right images
# Patient 1308: 2 left, 2 right images
# Patient 1309: 2 left, 2 right images
# Patient 1310: 2 left, 2 right images
# Patient 1311: 2 left, 2 right images
# Patient 1312: 2 left, 2 right images
# Patient 1313: 2 left, 2 right images
# Patient 1314: 2 left, 2 right images
# Patient 1315: 2 left, 2 right images
# Patient 1316: 2 left, 2 right images
# Patient 1317: 2 left, 2 right images
# Patient 1318: 2 left, 2 right images
# Patient 1319: 2 left, 2 right images
# Patient 1320: 2 left, 2 right images
# Patient 1321: 2 left, 2 right images
# Patient 1322: 2 left, 2 right images
# Patient 1323: 2 left, 2 right images
# Patient 1324: 2 left, 2 right images
# Patient 1325: 2 left, 2 right images
# Patient 1326: 2 left, 2 right images
# ...
# Patient 2764: 2 left, 2 right images
# Patient 2765: 2 left, 2 right images
# Patient 2766: 2 left, 2 right images
# Patient 2767: 2 left, 2 right images
# Patient 2768: 2 left, 2 right images
# Patient 2769: 2 left, 2 right images
# Patient 2770: 2 left, 2 right images
# Patient 2771: 2 left, 2 right images
# Patient 2772: 2 left, 2 right images
# Patient 2773: 2 left, 2 right images
# Patient 2774: 2 left, 2 right images
# Patient 2775: 2 left, 2 right images
# Patient 2776: 2 left, 2 right images
# Patient 2777: 2 left, 2 right images
# Patient 2778: 2 left, 2 right images
# Patient 2779: 2 left, 2 right images
# Patient 2780: 2 left, 2 right images
# Patient 2781: 2 left, 2 right images
# Patient 2782: 2 left, 2 right images
# Patient 2783: 2 left, 2 right images
# Patient 2784: 2 left, 2 right images
# Patient 2785: 2 left, 2 right images
# Patient 2786: 2 left, 2 right images
# Patient 2787: 2 left, 2 right images
# Patient 2788: 2 left, 2 right images
# Patient 2789: 2 left, 2 right images
# Patient 2790: 2 left, 2 right images
# Patient 2791: 2 left, 2 right images
# Patient 2792: 2 left, 2 right images
# Patient 2793: 2 left, 2 right images
# Patient 2794: 2 left, 2 right images
# Patient 2795: 2 left, 2 right images
# Patient 2796: 2 left, 2 right images
# Patient 2797: 2 left, 2 right images
# Patient 2798: 2 left, 2 right images
# Patient 2799: 2 left, 2 right images
# Patient 2800: 2 left, 2 right images
# Patient 2801: 2 left, 2 right images
# Patient 2802: 2 left, 2 right images
# Patient 2803: 2 left, 2 right images
# Patient 2804: 2 left, 2 right images
# Patient 2805: 2 left, 2 right images
# Patient 2806: 2 left, 2 right images
# Patient 2807: 2 left, 2 right images
# Patient 2808: 2 left, 2 right images
# Patient 2809: 2 left, 2 right images
# Patient 2810: 2 left, 2 right images
# Patient 2811: 2 left, 2 right images
# Patient 2812: 2 left, 2 right images
# Patient 2813: 2 left, 2 right images
# Patient 2814: 2 left, 2 right images
# Patient 2815: 2 left, 2 right images
# Patient 2816: 2 left, 2 right images
# Patient 2817: 2 left, 2 right images
# Patient 2818: 2 left, 2 right images
# Patient 2819: 2 left, 2 right images
# Patient 2820: 2 left, 2 right images
# Patient 2821: 2 left, 2 right images
# Patient 2822: 2 left, 2 right images
# Patient 2823: 2 left, 2 right images
# Patient 2824: 2 left, 2 right images
# Patient 2825: 2 left, 2 right images
# Patient 2826: 2 left, 2 right images
# Patient 2827: 2 left, 2 right images
# Patient 2828: 2 left, 2 right images
# Patient 2829: 2 left, 2 right images
# Patient 2830: 2 left, 2 right images
# Patient 2831: 2 left, 2 right images
# Patient 2832: 2 left, 2 right images
# Patient 2833: 2 left, 2 right images
# Patient 2834: 2 left, 2 right images
# Patient 2835: 2 left, 2 right images
# Patient 2836: 2 left, 2 right images
# Patient 2837: 2 left, 2 right images
# Patient 2838: 2 left, 2 right images
# Patient 2839: 2 left, 2 right images
# Patient 2840: 2 left, 2 right images
# Patient 2841: 2 left, 2 right images
# Patient 2842: 2 left, 2 right images
# Patient 2843: 2 left, 2 right images
# Patient 2844: 2 left, 2 right images
# Patient 2845: 2 left, 2 right images
# Patient 2846: 2 left, 2 right images
# Patient 2847: 2 left, 2 right images
# Patient 2848: 2 left, 2 right images
# Patient 2849: 2 left, 2 right images
# Patient 2850: 2 left, 2 right images
# Patient 2851: 2 left, 2 right images
# Patient 2852: 2 left, 2 right images
# Patient 2853: 2 left, 2 right images
# Patient 2854: 2 left, 2 right images
# Patient 2855: 2 left, 2 right images
# Patient 2856: 2 left, 2 right images
# Patient 2857: 2 left, 2 right images
# Patient 2858: 2 left, 2 right images
# Patient 2859: 2 left, 2 right images
# Patient 2860: 2 left, 2 right images
# Patient 2861: 2 left, 2 right images
# Patient 2862: 2 left, 2 right images
# Patient 2863: 2 left, 2 right images
# Patient 2864: 2 left, 2 right images
# Patient 2865: 2 left, 2 right images
# Patient 2866: 2 left, 2 right images
# Patient 2867: 2 left, 2 right images
# Patient 2868: 2 left, 2 right images
# Patient 2869: 2 left, 2 right images
# Patient 2870: 2 left, 2 right images
# Patient 2871: 2 left, 2 right images
# Patient 2872: 2 left, 2 right images
# Patient 2873: 2 left, 2 right images
# Patient 2874: 2 left, 2 right images
# Patient 2875: 2 left, 2 right images
# Patient 2876: 2 left, 2 right images
# Patient 2877: 2 left, 2 right images
# Patient 2878: 2 left, 2 right images
# Patient 2879: 2 left, 2 right images
# Patient 2880: 2 left, 2 right images
# Patient 2881: 2 left, 2 right images
# Patient 2882: 2 left, 2 right images
# Patient 2883: 2 left, 2 right images
# Patient 2884: 2 left, 2 right images
# Patient 2885: 2 left, 2 right images
# Patient 2886: 2 left, 2 right images
# Patient 2887: 2 left, 2 right images
# Patient 2888: 2 left, 2 right images
# Patient 2889: 2 left, 2 right images
# Patient 2890: 2 left, 2 right images
# Patient 2891: 2 left, 2 right images
# Patient 2892: 2 left, 2 right images
# Patient 2893: 2 left, 2 right images
# Patient 2894: 2 left, 2 right images
# Patient 2895: 2 left, 2 right images
# Patient 2896: 2 left, 2 right images
# Patient 2897: 2 left, 2 right images
# Patient 2898: 2 left, 2 right images
# Patient 2899: 2 left, 2 right images
# Patient 2900: 2 left, 2 right images
# Patient 2901: 2 left, 2 right images
# Patient 2902: 2 left, 2 right images
# Patient 2903: 2 left, 2 right images
# Patient 2904: 2 left, 2 right images
# Patient 2905: 2 left, 2 right images
# Patient 2906: 2 left, 2 right images
# Patient 2907: 2 left, 2 right images
# Patient 2908: 2 left, 2 right images
# Patient 2909: 2 left, 2 right images
# Patient 2910: 2 left, 2 right images
# Patient 2911: 2 left, 2 right images
# Patient 2912: 2 left, 2 right images
# Patient 2913: 2 left, 2 right images
# Patient 2914: 2 left, 2 right images
# Patient 2915: 2 left, 2 right images
# Patient 2916: 2 left, 2 right images
# Patient 2917: 2 left, 2 right images
# Patient 2918: 2 left, 2 right images
# Patient 2919: 2 left, 2 right images
# Patient 2920: 2 left, 2 right images
# Patient 2921: 2 left, 2 right images
# Patient 2922: 2 left, 2 right images
# Patient 2923: 2 left, 2 right images
# Patient 2924: 2 left, 2 right images
# Patient 2925: 2 left, 2 right images
# Patient 2926: 2 left, 2 right images
# Patient 2927: 2 left, 2 right images
# Patient 2928: 2 left, 2 right images
# Patient 2929: 2 left, 2 right images
# Patient 2930: 2 left, 2 right images
# Patient 2931: 2 left, 2 right images
# Patient 2932: 2 left, 2 right images
# Patient 2933: 2 left, 2 right images
# Patient 2934: 2 left, 2 right images
# Patient 2935: 2 left, 2 right images
# Patient 2936: 2 left, 2 right images
# Patient 2937: 2 left, 2 right images
# Patient 2938: 2 left, 2 right images
# Patient 2939: 2 left, 2 right images
# Patient 2940: 2 left, 2 right images
# Patient 2941: 2 left, 2 right images
# Patient 2942: 2 left, 2 right images
# Patient 2943: 2 left, 2 right images
# Patient 2944: 2 left, 2 right images
# Patient 2945: 2 left, 2 right images
# Patient 2946: 2 left, 2 right images
# Patient 2947: 2 left, 2 right images
# Patient 2948: 2 left, 2 right images
# Patient 2949: 2 left, 2 right images
# Patient 2950: 2 left, 2 right images
# Patient 2951: 2 left, 2 right images
# Patient 2952: 2 left, 2 right images
# Patient 2953: 2 left, 2 right images
# Patient 2954: 2 left, 2 right images
# Patient 2955: 2 left, 2 right images
# Patient 2956: 2 left, 2 right images
# Patient 2957: 2 left, 2 right images
# Patient 2958: 2 left, 2 right images
# Patient 2959: 2 left, 2 right images
# Patient 2960: 2 left, 2 right images
# Patient 2961: 2 left, 2 right images
# Patient 2962: 2 left, 2 right images
# Patient 2963: 2 left, 2 right images
# Patient 2964: 2 left, 2 right images
# Patient 2965: 2 left, 2 right images
# Patient 2966: 2 left, 2 right images
# Patient 2967: 2 left, 2 right images
# Patient 2968: 2 left, 2 right images
# Patient 2969: 2 left, 2 right images
# Patient 2970: 2 left, 2 right images
# Patient 2971: 2 left, 2 right images
# Patient 2972: 2 left, 2 right images
# Patient 2973: 2 left, 2 right images
# Patient 2974: 2 left, 2 right images
# Patient 2975: 2 left, 2 right images
# Patient 2976: 2 left, 2 right images
# Patient 2977: 2 left, 2 right images
# Patient 2978: 2 left, 2 right images
# Patient 2979: 2 left, 2 right images
# Patient 2980: 2 left, 2 right images
# Patient 2981: 2 left, 2 right images
# Patient 2982: 2 left, 2 right images
# Patient 2983: 2 left, 2 right images
# Patient 2984: 2 left, 2 right images
# Patient 2985: 2 left, 2 right images
# Patient 2986: 2 left, 2 right images
# Patient 2987: 2 left, 2 right images
# Patient 2988: 2 left, 2 right images
# Patient 2989: 2 left, 2 right images
# Patient 2990: 2 left, 2 right images
# Patient 2991: 2 left, 2 right images
# Patient 2992: 2 left, 2 right images
# Patient 2993: 2 left, 2 right images
# Patient 2994: 2 left, 2 right images
# Patient 2995: 2 left, 2 right images
# Patient 2996: 2 left, 2 right images
# Patient 2997: 2 left, 2 right images
# Patient 2998: 2 left, 2 right images
# Patient 2999: 2 left, 2 right images
# Patient 3000: 2 left, 2 right images
# Patient 3001: 2 left, 2 right images
# Patient 3002: 2 left, 2 right images
# Patient 3003: 2 left, 2 right images
# Patient 3004: 2 left, 2 right images
# Patient 3005: 2 left, 2 right images
# Patient 3006: 2 left, 2 right images
# Patient 3007: 2 left, 2 right images
# Patient 3008: 2 left, 2 right images
# Patient 3009: 2 left, 2 right images
# Patient 3010: 2 left, 2 right images
# Patient 3011: 2 left, 2 right images
# Patient 3012: 2 left, 2 right images
# Patient 3013: 2 left, 2 right images
# Patient 3014: 2 left, 2 right images
# Patient 3015: 2 left, 2 right images
# Patient 3016: 2 left, 2 right images
# Patient 3017: 2 left, 2 right images
# Patient 3018: 2 left, 2 right images
# Patient 3019: 2 left, 2 right images
# Patient 3020: 2 left, 2 right images
# Patient 3021: 2 left, 2 right images
# Patient 3022: 2 left, 2 right images
# Patient 3023: 2 left, 2 right images
# Patient 3024: 2 left, 2 right images
# Patient 3025: 2 left, 2 right images
# Patient 3026: 2 left, 2 right images
# Patient 3027: 2 left, 2 right images
# Patient 3028: 2 left, 2 right images
# Patient 3029: 2 left, 2 right images
# Patient 3030: 2 left, 2 right images
# Patient 3031: 2 left, 2 right images
# Patient 3032: 2 left, 2 right images
# Patient 3033: 2 left, 2 right images
# Patient 3034: 2 left, 2 right images
# Patient 3035: 2 left, 2 right images
# Patient 3036: 2 left, 2 right images
# Patient 3037: 2 left, 2 right images
# Patient 3038: 2 left, 2 right images
# Patient 3039: 2 left, 2 right images
# Patient 3040: 2 left, 2 right images
# Patient 3041: 2 left, 2 right images
# Patient 3042: 2 left, 2 right images
# Patient 3043: 2 left, 2 right images
# Patient 3044: 2 left, 2 right images
# Patient 3045: 2 left, 2 right images
# Patient 3046: 2 left, 2 right images
# Patient 3047: 2 left, 2 right images
# Patient 3048: 2 left, 2 right images
# Patient 3049: 2 left, 2 right images
# Patient 3050: 2 left, 2 right images
# Patient 3051: 2 left, 2 right images
# Patient 3052: 2 left, 2 right images
# Patient 3053: 2 left, 2 right images
# Patient 3054: 2 left, 2 right images
# Patient 3055: 2 left, 2 right images
# Patient 3056: 2 left, 2 right images
# Patient 3057: 2 left, 2 right images
# Patient 3058: 2 left, 2 right images
# Patient 3059: 2 left, 2 right images
# Patient 3060: 2 left, 2 right images
# Patient 3061: 2 left, 2 right images
# Patient 3062: 2 left, 2 right images
# Patient 3063: 2 left, 2 right images
# Patient 3064: 2 left, 2 right images
# Patient 3065: 2 left, 2 right images
# Patient 3066: 2 left, 2 right images
# Patient 3067: 2 left, 2 right images
# Patient 3068: 2 left, 2 right images
# Patient 3069: 2 left, 2 right images
# Patient 3070: 2 left, 2 right images
# Patient 3071: 2 left, 2 right images
# Patient 3072: 2 left, 2 right images
# Patient 3073: 2 left, 2 right images
# Patient 3074: 2 left, 2 right images
# Patient 3075: 2 left, 2 right images
# Patient 3076: 2 left, 2 right images
# Patient 3077: 2 left, 2 right images
# Patient 3078: 2 left, 2 right images
# Patient 3079: 2 left, 2 right images
# Patient 3080: 2 left, 2 right images
# Patient 3081: 2 left, 2 right images
# Patient 3082: 2 left, 2 right images
# Patient 3083: 2 left, 2 right images
# Patient 3084: 2 left, 2 right images
# Patient 3085: 2 left, 2 right images
# Patient 3086: 2 left, 2 right images
# Patient 3087: 2 left, 2 right images
# Patient 3088: 2 left, 2 right images
# Patient 3089: 2 left, 2 right images
# Patient 3090: 2 left, 2 right images
# Patient 3091: 2 left, 2 right images
# Patient 3092: 2 left, 2 right images
# Patient 3093: 2 left, 2 right images
# Patient 3094: 2 left, 2 right images
# Patient 3095: 2 left, 2 right images
# Patient 3096: 2 left, 2 right images
# Patient 3097: 2 left, 2 right images
# Patient 3098: 2 left, 2 right images
# Patient 3099: 2 left, 2 right images
# Patient 3100: 2 left, 2 right images
# Patient 3101: 2 left, 2 right images
# Patient 3102: 2 left, 2 right images
# Patient 3103: 2 left, 2 right images
# Patient 3104: 2 left, 2 right images
# Patient 3105: 2 left, 2 right images
# Patient 3106: 2 left, 2 right images
# Patient 3107: 2 left, 2 right images
# Patient 3108: 2 left, 2 right images
# Patient 3109: 2 left, 2 right images
# Patient 3110: 2 left, 2 right images
# Patient 3111: 2 left, 2 right images
# Patient 3112: 2 left, 2 right images
# Patient 3113: 2 left, 2 right images
# Patient 3114: 2 left, 2 right images
# Patient 3115: 2 left, 2 right images
# Patient 3116: 2 left, 2 right images
# Patient 3117: 2 left, 2 right images
# Patient 3118: 2 left, 2 right images
# Patient 3119: 2 left, 2 right images
# Patient 3120: 2 left, 2 right images
# Patient 3121: 2 left, 2 right images
# Patient 3122: 2 left, 2 right images
# Patient 3123: 2 left, 2 right images
# Patient 3124: 2 left, 2 right images
# Patient 3125: 2 left, 2 right images
# Patient 3126: 2 left, 2 right images
# Patient 3127: 2 left, 2 right images
# Patient 3128: 2 left, 2 right images
# Patient 3129: 2 left, 2 right images
# Patient 3130: 2 left, 2 right images
# Patient 3131: 2 left, 2 right images
# Patient 3132: 2 left, 2 right images
# Patient 3133: 2 left, 2 right images
# Patient 3134: 2 left, 2 right images
# Patient 3135: 2 left, 2 right images
# Patient 3136: 2 left, 2 right images
# Patient 3137: 2 left, 2 right images
# Patient 3138: 2 left, 2 right images
# Patient 3139: 2 left, 2 right images
# Patient 3140: 2 left, 2 right images
# Patient 3141: 2 left, 2 right images
# Patient 3142: 2 left, 2 right images
# Patient 3143: 2 left, 2 right images
# Patient 3144: 2 left, 2 right images
# Patient 3145: 2 left, 2 right images
# Patient 3146: 2 left, 2 right images
# Patient 3147: 2 left, 2 right images
# Patient 3148: 2 left, 2 right images
# Patient 3149: 2 left, 2 right images
# Patient 3150: 2 left, 2 right images
# Patient 3151: 2 left, 2 right images
# Patient 3152: 2 left, 2 right images
# Patient 3153: 2 left, 2 right images
# Patient 3154: 2 left, 2 right images
# Patient 3155: 2 left, 2 right images
# Patient 3156: 2 left, 2 right images
# Patient 3157: 2 left, 2 right images
# Patient 3158: 2 left, 2 right images
# Patient 3159: 2 left, 2 right images
# Patient 3160: 2 left, 2 right images
# Patient 3161: 2 left, 2 right images
# Patient 3162: 2 left, 2 right images
# Patient 3163: 2 left, 2 right images
# Patient 3164: 2 left, 2 right images
# Patient 3165: 2 left, 2 right images
# Patient 3166: 2 left, 2 right images
# Patient 3167: 2 left, 2 right images
# Patient 3168: 2 left, 2 right images
# Patient 3169: 2 left, 2 right images
# Patient 3170: 2 left, 2 right images
# Patient 3171: 2 left, 2 right images
# Patient 3172: 2 left, 2 right images
# Patient 3173: 2 left, 2 right images
# Patient 3174: 2 left, 2 right images
# Patient 3175: 2 left, 2 right images
# Patient 3176: 2 left, 2 right images
# Patient 3177: 2 left, 2 right images
# Patient 3178: 2 left, 2 right images
# Patient 3179: 2 left, 2 right images
# Patient 3180: 2 left, 2 right images
# Patient 3181: 2 left, 2 right images
# Patient 3182: 2 left, 2 right images
# Patient 3183: 2 left, 2 right images
# Patient 3184: 2 left, 2 right images
# Patient 3185: 2 left, 2 right images
# Patient 3186: 2 left, 2 right images
# Patient 3187: 2 left, 2 right images
# Patient 3188: 2 left, 2 right images
# Patient 3189: 2 left, 2 right images
# Patient 3190: 2 left, 2 right images
# Patient 3191: 2 left, 2 right images
# Patient 3192: 2 left, 2 right images
# Patient 3193: 2 left, 2 right images
# Patient 3194: 2 left, 2 right images
# Patient 3195: 2 left, 2 right images

# %%
for i in range(len(train_dataset)):
    try:
        images, labels = train_dataset[i]
        print(f"Patient {i}: Sequence size {images.size()}, Labels: {labels}")
    except Exception as e:
        print(f"Error for Patient {i}: {e}")
# Out:
# Error for Patient 0: stack expects a non-empty TensorList
# Patient 1: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 2: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 3: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 4: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 5: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 1., 0.])
# Patient 6: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 7: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 8: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 9: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 10: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 11: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 12: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 13: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 14: stack expects a non-empty TensorList
# Patient 15: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 16: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 17: stack expects a non-empty TensorList
# Patient 18: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 1., 0.])
# Patient 19: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 20: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 21: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 22: stack expects a non-empty TensorList
# Patient 23: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 24: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 25: stack expects a non-empty TensorList
# Patient 26: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 27: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 28: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Error for Patient 29: stack expects a non-empty TensorList
# Error for Patient 30: stack expects a non-empty TensorList
# Error for Patient 31: stack expects a non-empty TensorList
# Error for Patient 32: stack expects a non-empty TensorList
# Patient 33: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 34: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 35: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 36: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 37: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 38: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 39: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 40: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 41: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 42: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Error for Patient 43: stack expects a non-empty TensorList
# Error for Patient 44: stack expects a non-empty TensorList
# Error for Patient 45: stack expects a non-empty TensorList
# Patient 46: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 1., 0., 0., 0., 0.])
# Patient 47: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 48: stack expects a non-empty TensorList
# Patient 49: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 50: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 51: stack expects a non-empty TensorList
# Error for Patient 52: stack expects a non-empty TensorList
# Patient 53: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 54: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 55: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 56: stack expects a non-empty TensorList
# Patient 57: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 58: stack expects a non-empty TensorList
# Patient 59: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 60: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 61: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 1., 0.])
# Patient 62: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 63: stack expects a non-empty TensorList
# Patient 64: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 65: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 66: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 67: stack expects a non-empty TensorList
# Patient 68: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 69: stack expects a non-empty TensorList
# Error for Patient 70: stack expects a non-empty TensorList
# Patient 71: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 72: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 73: stack expects a non-empty TensorList
# Patient 74: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 75: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Error for Patient 76: stack expects a non-empty TensorList
# Patient 77: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 78: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 79: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 80: stack expects a non-empty TensorList
# Patient 81: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 82: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 83: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 84: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 85: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 86: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 87: stack expects a non-empty TensorList
# Error for Patient 88: stack expects a non-empty TensorList
# Patient 89: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 90: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 91: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 92: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 93: stack expects a non-empty TensorList
# Patient 94: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 95: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 96: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 97: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 98: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 99: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 100: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 101: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 102: stack expects a non-empty TensorList
# Patient 103: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 104: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 105: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 106: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 107: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 108: stack expects a non-empty TensorList
# Patient 109: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 110: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 111: stack expects a non-empty TensorList
# Patient 112: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 113: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 114: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 115: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 116: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 117: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 118: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 119: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 120: stack expects a non-empty TensorList
# Patient 121: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 122: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 123: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 124: stack expects a non-empty TensorList
# Patient 125: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 126: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 127: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 128: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 129: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 130: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 131: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 132: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 133: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Error for Patient 134: stack expects a non-empty TensorList
# Error for Patient 135: stack expects a non-empty TensorList
# Patient 136: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 137: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 138: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 139: stack expects a non-empty TensorList
# Patient 140: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Error for Patient 141: stack expects a non-empty TensorList
# Patient 142: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 143: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 144: stack expects a non-empty TensorList
# Patient 145: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 146: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 147: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 148: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 149: stack expects a non-empty TensorList
# Patient 150: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 151: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 152: stack expects a non-empty TensorList
# Patient 153: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 154: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 1., 0., 0., 0., 0.])
# Patient 155: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 156: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 157: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 158: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 159: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 160: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 161: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 162: stack expects a non-empty TensorList
# Patient 163: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 164: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 165: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 166: stack expects a non-empty TensorList
# Patient 167: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 168: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 169: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 170: stack expects a non-empty TensorList
# Patient 171: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 172: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 173: stack expects a non-empty TensorList
# Error for Patient 174: stack expects a non-empty TensorList
# Error for Patient 175: stack expects a non-empty TensorList
# Error for Patient 176: stack expects a non-empty TensorList
# Error for Patient 177: stack expects a non-empty TensorList
# Error for Patient 178: stack expects a non-empty TensorList
# Patient 179: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 180: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 181: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 182: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 183: stack expects a non-empty TensorList
# Error for Patient 184: stack expects a non-empty TensorList
# Patient 185: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 186: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 187: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 188: stack expects a non-empty TensorList
# Patient 189: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 190: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 191: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 192: stack expects a non-empty TensorList
# Patient 193: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 194: stack expects a non-empty TensorList
# Patient 195: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 196: stack expects a non-empty TensorList
# Patient 197: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 198: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 199: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 200: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 201: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 202: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 203: stack expects a non-empty TensorList
# Patient 204: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 205: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 206: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 207: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 208: stack expects a non-empty TensorList
# Patient 209: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 210: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 211: stack expects a non-empty TensorList
# Patient 212: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 213: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Error for Patient 214: stack expects a non-empty TensorList
# Patient 215: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 216: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 217: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Error for Patient 218: stack expects a non-empty TensorList
# Patient 219: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 1., 0.])
# Patient 220: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 221: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 222: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 223: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 224: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 225: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 226: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 227: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Patient 228: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 0., 0., 1.])
# Error for Patient 229: stack expects a non-empty TensorList
# Patient 230: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 231: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 232: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Error for Patient 233: stack expects a non-empty TensorList
# Patient 234: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 1., 0., 0., 0., 0., 0., 0.])
# Patient 235: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Patient 236: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 0., 1., 0., 0.])
# Patient 237: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([1., 0., 0., 0., 0., 0., 0., 0.])
# Patient 238: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# Error for Patient 239: stack expects a non-empty TensorList
# Error for Patient 240: stack expects a non-empty TensorList
# Patient 241: Sequence size torch.Size([2, 6, 224, 224]), Labels: tensor([0., 0., 0., 1., 0., 0., 0., 0.])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 for i in range(len(train_dataset)):
#       2     try:
# ----> 3         images, labels = train_dataset[i]
#       4         print(f"Patient {i}: Sequence size {images.size()}, Labels: {labels}")
#       5     except Exception as e:
#
# Cell In[4], line 55, in FundusSequenceDataset.__getitem__(self, idx)
#      53 for _, row in patient_data.iterrows():
#      54     left_img = cv2.imread(row['Left-Fundus'])
# ---> 55     right_img = cv2.imread(row['Right-Fundus'])
#      57     # Resize and concatenate
#      58     left_img = cv2.resize(left_img, (IMG_WIDTH, IMG_HEIGHT))
#
# KeyboardInterrupt:
